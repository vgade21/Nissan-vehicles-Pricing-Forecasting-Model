# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %%
df_spec = pd.read_csv('../01_Outputs/df_Preparation.csv')
# Out:
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/119868344.py:1: DtypeWarning: Columns (15,20,22,23,32,37,39,40,44,54,63,74,85,86,87,96,98,125,141,143,145,152,162,163,166,169,175,184,186,208,209,212,218,221,222,223,228,230,231,234,236,243,245,246,247,248,249,250,252,253,255,257,258,266,270,277,279,289,290,295,304,307,321,324,325,335,337,338,339,340,341,343,344,356,361,363,412,417,422,425,430,431,434,444,448,450,453,458,460,461,463,466,467,473,474,480,484,485,486,487,488,489,492,494,498,500,501,502,503,506,509,511,513,515,516,517,518,519,520,522,523,524,525,526,527,528,531,533,535,536,538,540,541,545,551,552,553,557,558,560,561,562,568,569,570,571,572,573,574,576,581,583,584,585,590,591,592,593,595,596,597,602,603,604,606,608,618,619,621,639,645,646,649,658,659,660,661,662,667,670,671,672,673,674,679,682,683,684,685,686,690,691,692,693,695,696,697,708,709,711,719,720,722,723,725,728,730,735,785,803,807,818,819,821,822,829,834,837,839,842,855,861,868,873,902,935,963,964,966,980,999,1004,1008,1018,1023,1025,1026,1030,1031,1039,1040,1041,1042,1043,1044,1045,1046,1047,1048,1049,1050,1055,1056,1057,1058,1059,1060,1061,1070,1072,1073,1074,1075,1076,1078,1079,1080,1082,1086,1090,1092,1094,1096,1097,1117,1120,1121,1124,1125,1127,1128,1129,1130,1131,1132,1133,1134,1149,1150,1151,1152,1156,1162,1168,1173,1188,1189,1193,1194,1209,1215,1217,1218,1236,1237,1238,1242,1244,1256,1257,1268,1269,1271,1307,1384,1410,1411,1412,1421,1422,1423,1426,1869,1874,1875,1876,1877,1878,1879,1880,1883,1884,1887,1888,1889,1892,1895,1897,1898,1905,1907,1913,1924,1931,1932,1947,1952,1957,1958,1959,1965,1969,1971,1974,1975,1979,1980,1982,1983,1984,1987,1988,1989,1991,1997,1998,1999,2000,2001,2002,2003,2007,2008,2019,2027,2029,2037,2038,2039,2041,2042,2046,2047,2049,2050,2051,2052,2054,2055,2056,2057,2058,2059,2061,2063,2065,2067,2069,2075,2077,2085,2092,2096,2102,2107,2108,2109,2110,2111,2112,2113,2129,2168,2178,2183,2186,2194,2195,2200,2202,2203,2205,2206,2207,2208,2210,2212,2214,2216,2224,2225,2229,2230,2243,2266,2267,2291,2297,2299,2300,2310,2311,2314,2315,2316,2317,2319,2321,2325,2329,2347,2348,2350,2356,2361,2364,2370,2373,2374,2377,2385,2387,2388,2393,2396,2400,2406,2408,2409,2410,2411,2412,2413,2414,2417,2424,2426,2428,2435,2436,2438,2459,2464,2465,2467,2469,2475,2489,2491,2493,2497,2498,2507,2512,2516,2518,2519,2521,2522,2523,2525,2526,2527,2529,2530,2531,2542,2546,2550,2639,2641,2648,2652,2653,2663,2671,2672,2678,2681,2682) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_spec = pd.read_csv('../01_Outputs/df_Preparation.csv')

# %% [markdown]
# # Features

# %% [markdown]
# Drop empty columns

# %%
df_spec =  df_spec.dropna(axis=1, how='all')

# %% [markdown]
# Drop fetures with NA, minimum number of NA can be the number of electric vehicles
# (Because new feature would not exist in the privious model year, to include high NA value column, and make NA zero)

# %% [markdown]
# ## Data cleansing

# %% [markdown]
# ### Profiles

# %%
df_spec = df_spec[df_spec['SPEC_Data status']=='full specs']
df_spec = df_spec[df_spec['SPEC_colour & trim status']=='up to date']
df_spec = df_spec[df_spec['SPEC_specs status'] !='out of date']

# %%
profile = ['SPEC_Name', 'SPEC_Unique Identity', 'SPEC_Data date','SPEC_Version state',  'SPEC_Data status','SPEC_Model year',
            'SPEC_Make','SPEC_Model','SPEC_Model generation', 'SPEC_Version name',
            'SPEC_Trim level', 'SPEC_trim classification',
            'SPEC_Number of doors','SPEC_Body type', 'SPEC_cab type',
            'SPEC_Vehicle type','SPEC_Country of assembly',
            'SPEC_Make continent group','SPEC_facelift generation','SPEC_JATO global segment', 'SPEC_JATO regional segment'
           ]

# %%
df_spec.columns = [col.replace('SPEC_', 'PROFILE_') if col in profile else col for col in df_spec.columns]

# %%
target = ['SPEC_Retail price', 'SPEC_Base price', 'Weighted_RetailPrice',
            'SPEC_Retail price including delivery charge','Volume','Standardized_VolumebyModel', 'MSRPxVolumebyModel']

# %%
df_spec.columns = ['TARGET_' + col.replace('SPEC_', '') if col in target else col for col in df_spec.columns]

# %%
df_spec = pd.concat([df_spec, pd.get_dummies(df_spec['SPEC_type'], prefix='SPEC_Enginetype')], axis=1)
df_spec = pd.concat([df_spec, pd.get_dummies(df_spec['SPEC_wheelbase type'], prefix='SPEC_Wheelbase')], axis=1)
df_spec = pd.concat([df_spec, pd.get_dummies(df_spec['SPEC_Driven wheels'], prefix='SPEC_Drivenwheels')], axis=1)
df_spec = pd.concat([df_spec, pd.get_dummies(df_spec['SPEC_roof type'], prefix='SPEC_rooftype')], axis=1)
df_spec = pd.concat([df_spec, pd.get_dummies(df_spec['SPEC_duty rating'], prefix='SPEC_dutyrating')], axis=1)
df_spec = pd.concat([df_spec, pd.get_dummies(df_spec['SPEC_Fuel type'], prefix='SPEC_fueltype')], axis=1)
df_spec = pd.concat([df_spec, pd.get_dummies(df_spec['SPEC_Compressor'], prefix='SPEC_Compressor')], axis=1)
df_spec = pd.concat([df_spec, pd.get_dummies(df_spec['SPEC_injection/carburetion'], prefix='SPEC_injection')], axis=1)
df_spec = pd.concat([df_spec, pd.get_dummies(df_spec['SPEC_hybrid type293'], prefix='SPEC_hybridtype')], axis=1)
df_spec = pd.concat([df_spec, pd.get_dummies(df_spec['SPEC_main seat material'], prefix='SPEC_Seatmaterial')], axis=1)
df_spec = pd.concat([df_spec, pd.get_dummies(df_spec['SPEC_type812'], prefix='SPEC_RRseat_type')], axis=1)
df_spec = pd.concat([df_spec, pd.get_dummies(df_spec['SPEC_air conditioning type'], prefix='SPEC_Airconditioningtype')], axis=1)
df_spec = pd.concat([df_spec, pd.get_dummies(df_spec['PROFILE_cab type'], prefix='SPEC_cab_type')], axis=1)
df_spec = pd.concat([df_spec, pd.get_dummies(df_spec['PROFILE_Make continent group'], prefix='SPEC_Continentgroup')], axis=1)
df_spec = pd.concat([df_spec, pd.get_dummies(df_spec['PROFILE_Country of assembly'], prefix='SPEC_CountryOfAssembly')], axis=1)
df_spec = pd.concat([df_spec, pd.get_dummies(df_spec['PROFILE_Model year'], prefix='PROFILE_MY')], axis=1)
df_spec = pd.concat([df_spec, pd.get_dummies(df_spec['PROFILE_Make'], prefix='PROFILE_Make')], axis=1)
df_spec = pd.concat([df_spec, pd.get_dummies(df_spec['PROFILE_Body type'], prefix='PROFILE_Bodytype')], axis=1)
df_spec = pd.concat([df_spec, pd.get_dummies(df_spec['Segment_Name'], prefix='Segment')], axis=1)

# %%
df_spec['SPEC_ManualTransmission'] = df_spec['SPEC_Transmission type'].apply(lambda x: 1 if x=='manual' else 0)
# Out:
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2526431691.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_spec['SPEC_ManualTransmission'] = df_spec['SPEC_Transmission type'].apply(lambda x: 1 if x=='manual' else 0)

# %%
drop_lst = ['SPEC_Compressor','SPEC_Fuel type','SPEC_duty rating','SPEC_roof type','SPEC_Driven wheels', 'SPEC_wheelbase type', 'SPEC_type','SPEC_Country', 'SPEC_Transmission type', 'SPEC_Date of change', 'SPEC_Conclude date', 
    'SPEC_Data completeness',  'SPEC_colour & trim status', 
    'SPEC_key leasing items', 'SPEC_option content status', 'SPEC_option prices status', 'SPEC_prices status', 'SPEC_specs status',
    'SPEC_incentive status',   'SPEC_Global equivalent make', 
    'SPEC_Global equivalent model', 'SPEC_Model descriptor',  
    'SPEC_Special edition base UID',  'SPEC_trim code', 'SPEC_Pricing descriptor', 
    'SPEC_Powertrain type', 'SPEC_platform code', 
    'SPEC_Price currency', 
    'SPEC_Country specific price',   'SPEC_Net prices', 
    'SPEC_Regional prices', 'SPEC_Indicative prices only', 
    'SPEC_monthly leasing cost', 'SPEC_Source of price list', 'SPEC_Latest price list number', 'SPEC_Latest price list date', 
    'SPEC_Version id',  'SPEC_VIN', 
    "SPEC_Manufacturer's code", "SPEC_Local manufacturer's code",
    'SPEC_Make group', 'SPEC_Model group', 
    'SPEC_Purchase condition', 'SPEC_Plant of assembly', 'SPEC_Template version', 
    'SPEC_Local language','SPEC_language5', 'SPEC_make8', 'SPEC_model9', 'SPEC_version name10', 'SPEC_trim level11', 
    'SPEC_Date introduced', 'SPEC_Version introduced', 
    'SPEC_Model introduced',  'SPEC_Model Year Fraction',  
    'SPEC_Version availability', 'SPEC_showroom arrival date', 'DATE']

# %%
df_spec = df_spec[[col for col in df_spec.columns if col not in drop_lst]]

# %%
df_clean = df_spec.copy()

# %%
for col_name in df_clean.columns:
    if ('yes' in df_clean[col_name].unique()) & ('no' in df_clean[col_name].unique()):
        df_clean[col_name] = df_clean[col_name].str.replace('yes', '1').str.replace('no', '0')
        try:
            df_clean[col_name] = df_clean[col_name].fillna(0)
            df_clean[col_name] = df_clean[col_name].astype(int)
        except:
            pass
    if ('not available' in df_clean[col_name].unique()) & ('standard' in df_clean[col_name].unique()):
        df_clean[col_name] = df_clean[col_name].str.replace('standard', '1').str.replace('not available', '0').str.replace('option', '0')
        try:
            df_clean[col_name] = df_clean[col_name].fillna(0)
            df_clean[col_name] = df_clean[col_name].astype(int)
        except:
            pass
# Out:
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2904887320.py:2: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if ('yes' in df_clean[col_name].unique()) & ('no' in df_clean[col_name].unique()):
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2904887320.py:9: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if ('not available' in df_clean[col_name].unique()) & ('standard' in df_clean[col_name].unique()):

# %%
df_datatype = pd.DataFrame(df_clean.filter(like='SPEC_', axis=1).dtypes, columns=['Datatype'])
object_index = df_datatype[df_datatype['Datatype'] == 'object'].index.tolist()
len(object_index)
df_clean = df_clean[~df_clean['Segment_Competing_Nissan_Model'].isna()]

# %%
df_clean['SPEC_cab_extended'] = (df_clean['SPEC_cab type33'] == 'extended').astype(int)
df_clean['SPEC_cab_crew'] = (df_clean['SPEC_cab type33'] == 'crew').astype(int)
df_clean['SPEC_cab_regular'] = (df_clean['SPEC_cab type33'] == 'regular').astype(int)
df_clean['SPEC_roof_standard'] = (df_clean['SPEC_roof type34'] == 'standard').astype(int)
df_clean['SPEC_roof_high'] = (df_clean['SPEC_roof type34'] == 'high').astype(int)
df_clean['SPEC_roof_semi-high'] = (df_clean['SPEC_roof type34'] == 'semi-high').astype(int)
df_clean['SPEC_roof_extra-high'] = (df_clean['SPEC_roof type34'] == 'extra-high').astype(int)
df_clean['SPEC_wheelbase_short'] = (df_clean['SPEC_wheelbase type35'] == 'short').astype(int)
df_clean['SPEC_wheelbase_long'] = (df_clean['SPEC_wheelbase type35'] == 'long').astype(int)
df_clean['SPEC_wheelbase_medium'] = (df_clean['SPEC_wheelbase type35'] == 'medium').astype(int)
df_clean['SPEC_step_rear'] = (df_clean['SPEC_location50'] == 'rear').astype(int)
df_clean['SPEC_step_side'] = (df_clean['SPEC_location50'] == 'side').astype(int)
df_clean['SPEC_step_rearside'] = (df_clean['SPEC_location50'] == 'rear:side ').astype(int)
df_clean['SPEC_step_illuminated'] = (df_clean['SPEC_illuminated'] == '1').astype(int)
df_clean['SPEC_step_retractable'] = df_clean.apply(lambda x: 1 if (x['SPEC_retractable']=='electric:')\
    or (x['SPEC_power retractable'] == '1')\
    or (x['SPEC_power retractable'] == ' :1')\
    or (x['SPEC_power retractable'] == '0:1') else 0, axis=1).fillna(0)
#What's towing class: https://www.curtmfg.com/types-trailer-hitches
df_clean['SPEC_towingclass_I'] = (df_clean['SPEC_towing class'] == 'I').astype(int)
df_clean['SPEC_towingclass_II'] = (df_clean['SPEC_towing class'] == 'II').astype(int)
df_clean['SPEC_towingclass_III'] = (df_clean['SPEC_towing class'] == 'III').astype(int)
df_clean['SPEC_towingclass_IV'] = (df_clean['SPEC_towing class'] == 'IV').astype(int)
df_clean['SPEC_Mudflaps_FR'] = (df_clean['SPEC_location60'] == 'front').astype(int)
df_clean['SPEC_Mudflaps_RR'] = (df_clean['SPEC_location60'] == 'rear').astype(int)
df_clean['SPEC_Mudflaps_FRRR'] = (df_clean['SPEC_location60'] == 'front:rear').astype(int)
df_clean['SPEC_Bumper_FRRR'] = (df_clean['SPEC_location81'] == 'front:rear').astype(int)
df_clean['SPEC_Bumper_FR'] = (df_clean['SPEC_location81'] == 'front').astype(int)
df_clean['SPEC_tonneaucover'] = (df_clean['SPEC_pickup bed cover'] == 'tonneau cover').astype(int)
df_clean['SPEC_boxlength_regular'] = (df_clean['SPEC_box length'] == 'regular').astype(int)
df_clean['SPEC_boxlength_long'] = (df_clean['SPEC_box length'] == 'long').astype(int)
df_clean['SPEC_boxlength_short'] = (df_clean['SPEC_box length'] == 'short').astype(int)
df_clean['SPEC_Readinglight_FR'] = (df_clean['SPEC_location116'] == 'front').astype(int)
df_clean['SPEC_Readinglight_RR'] = (df_clean['SPEC_location116'] == 'front:rear').astype(int)
df_clean['SPEC_Readinglight_FRRR'] = (df_clean['SPEC_location116'] == 'rear').astype(int)
df_clean['SPEC_Vanitymirror_Driver'] = (df_clean['SPEC_location127'] == 'driver').astype(int)
df_clean['SPEC_Vanitymirror_DriverPassenger'] = (df_clean['SPEC_location127'] == 'driver:passenger').astype(int)
df_clean['SPEC_Vanitymirror_Passenger'] = (df_clean['SPEC_location127'] == 'passenger').astype(int)
df_clean['SPEC_Vanitymirror_illumi'] = ((df_clean['SPEC_illuminated128'] == '1') \
                                        | (df_clean['SPEC_illuminated128'] == '0:1')).astype(int)
df_clean['SPEC_stop'] = (df_clean['SPEC_stop/go function'] == 'stop').astype(int)
df_clean['SPEC_stopandgo'] = (df_clean['SPEC_stop/go function'] == 'stop & go').astype(int)
df_clean['SPEC_parkingdistsys_RR'] = (df_clean['SPEC_location132'] == 'rear').astype(int)
df_clean['SPEC_parkingdistsys_FRRR'] = (df_clean['SPEC_location132'] == 'front:rear').astype(int)
df_clean['SPEC_parkingdistsys_FRRRSide'] = (df_clean['SPEC_location132'] == 'front:rear:side').astype(int)
df_clean['SPEC_parkingdistsys_RRSide'] = (df_clean['SPEC_location132'] == 'rear:side').astype(int)
df_clean['SPEC_internetmap'] = (df_clean['SPEC_data feed'] == 'internet').astype(int)
df_clean['SPEC_colordisplay'] = (df_clean['SPEC_display type'] == 'color').astype(int)
df_clean['SPEC_OTAupdates'] = (df_clean['SPEC_type151'] == 'OTA updates').astype(int)
df_clean['SPEC_num12V'] = df_clean['SPEC_number of outlets'].fillna(0).\
    astype(str).apply(lambda x: sum([float(i) for i in x.split(':') if i!=' '])).astype(int)
df_clean['SPEC_numUSB'] = df_clean['SPEC_number'].fillna(0).\
    astype(str).apply(lambda x: sum([float(i) for i in x.split(':') if i!=' '])).astype(int)

# Multiple funciton display(Navigation display, TFT meter, etc.)
df_clean.loc[df_clean["SPEC_location324"]=='Dashboard centre 2', 'SPEC_location324'] = 'Dashboard centre 1'
df_clean.loc[df_clean["SPEC_location324"]=='Dashboard centre 1: ', 'SPEC_location324'] = 'Dashboard centre 1'
df_clean.loc[df_clean["SPEC_location324"]=='Instrument panel 1: ', 'SPEC_location324'] = 'Instrument panel 1'
df_clean.loc[df_clean["SPEC_location324"]=='Instrument panel 1:Dashboard centre 1: ', 'SPEC_location324'] = 'Instrument panel 1:Dashboard centre 1'
df_clean.loc[df_clean["SPEC_location324"]=='Instrument panel 2:Dashboard centre 1', 'SPEC_location324'] = 'Instrument panel 1:Dashboard centre 1'
## Size of the each display
df_clean['SPEC_multifuncdisplay_Instrument1_size'] = df_clean.apply(lambda x:
        str(x['SPEC_screen size (in)325']).split(':')[0] 
        if  (x['SPEC_location324'] == 'Instrument panel 1:Dashboard centre 1:Dashboard centre 2')|\
            (x['SPEC_location324'] == 'Instrument panel 1:Dashboard centre 1')|\
            (x['SPEC_location324'] == 'Instrument panel 1:Instrument panel 2:Dashboard centre 1')|\
            (x['SPEC_location324'] == 'Instrument panel 1')
        else 0, axis=1
    ).replace('nan', 0).replace(' ', '8.0').astype(float)
df_clean['SPEC_multifuncdisplay_Instrument2_size'] = df_clean.apply(lambda x:
        str(x['SPEC_screen size (in)325']).split(':')[1] 
        if  (x['SPEC_location324'] == 'Instrument panel 1:Instrument panel 2:Dashboard centre 1')\
        else 0, axis=1
    ).replace('nan', 0).astype(float)
df_clean['SPEC_multifuncdisplay_Dashboard1_size'] = df_clean.apply(lambda x:
        str(x['SPEC_screen size (in)325']).split(':')[0]\
        if  ((x['SPEC_location324'] == 'Instrument panel 1:Dashboard centre 1:Dashboard centre 2')|\
            (x['SPEC_location324'] == 'Instrument panel 1:Dashboard centre 1'))&\
            (len(str(x['SPEC_screen size (in)325']).split(':'))<=1)\
        else str(x['SPEC_screen size (in)325']).split(':')[1]\
        if  ((x['SPEC_location324'] == 'Instrument panel 1:Dashboard centre 1:Dashboard centre 2')|\
            (x['SPEC_location324'] == 'Instrument panel 1:Dashboard centre 1'))
        else str(x['SPEC_screen size (in)325']).split(':')[0]\
        if  (x['SPEC_location324'] == 'Dashboard centre 1')|\
            (x['SPEC_location324'] == 'Dashboard centre 1:Dashboard centre 2')
        else str(x['SPEC_screen size (in)325']).split(':')[2]\
        if  (x['SPEC_location324'] == 'Instrument panel 1:Instrument panel 2:Dashboard centre 1')\
        else 0
        , axis=1
    ).replace('nan', 0).replace(' ', 12.3).astype(float)
df_clean['SPEC_multifuncdisplay_Dashboard2_size'] = df_clean.apply(lambda x:
        str(x['SPEC_screen size (in)325']).split(':')[1]\
        if  (x['SPEC_location324'] == 'Dashboard centre 1:Dashboard centre 2')&\
            (len(str(x['SPEC_screen size (in)325']).split(':'))>1)\
        else     str(x['SPEC_screen size (in)325']).split(':')[0]\
        if  (x['SPEC_location324'] == 'Dashboard centre 1:Dashboard centre 2')
        else str(x['SPEC_screen size (in)325']).split(':')[2]\
        if  (x['SPEC_location324'] == 'Instrument panel 1:Dashboard centre 1:Dashboard centre 2')\
        else 0
        , axis=1
    ).replace('nan', 0).astype(float)
df_clean['SPEC_multifuncdisplay_numtouchscreen'] = df_clean["SPEC_touch screen328"].apply(lambda x:\
    sum([float(i) for i in str(x).split(':') if i !=' ']))
df_clean['SPEC_multifuncdisplay_nummultitouchscreen'] = df_clean["SPEC_multi-touch screen329"].apply(lambda x:\
    sum([float(i) for i in str(x).split(':') if i !=' ']))



df_clean['SPEC_entertainmentscreen_num'] = df_clean["SPEC_screen location"].apply(lambda x:
    1 if (x == 'front') or (x == 'single rear middle')\
    else 2 if (x == 'front:single rear middle') or (x=='back of front seats') or (x=='back of rear seats')\
    else 3 if x == 'front:back of front seats'\
    else 4 if x == 'front:single rear middle:back of front seats'\
    else 0).fillna(0)
df_clean['SPEC_entertainmentscreen_numDVDplayer'] = df_clean["SPEC_DVD"].apply(lambda x:
    1 if (x == '1') or (x == '0:1') or (x == '1: ')\
    else 2 if (x == '0:1:1')\
    else 0).fillna(0)
df_clean['SPEC_entertainmentscreen_numBluerayplayer'] = df_clean["SPEC_blu-ray"].apply(lambda x:
    1 if (x == '1') or (x == '0:1')\
    else 2 if (x == '1:1: ')\
    else 0).fillna(0)
df_clean['SPEC_entertainmentscreen_biggestsize'] = df_clean["SPEC_screen size (in)168"].apply(lambda x:
    max([float(i) for i in str(x).split(':') if i !=' '])).fillna(0)
df_clean['SPEC_entertainmentscreen_touchscreen'] = df_clean["SPEC_touch screen170"].apply(lambda x:
    sum([float(i) for i in str(x).split(':') if i !=' '])).fillna(0).astype(int)

df_clean['SPEC_smartkey_auto'] = (df_clean['SPEC_type175'] == 'automatic').astype(int)
df_clean['SPEC_smartkey_manual'] = (df_clean['SPEC_type175'] == 'manual').astype(int)
df_clean['SPEC_virtualassist_Alexa']= (df_clean['SPEC_virtual assistant'] == 'Alexa').astype(int)
df_clean['SPEC_virtualassist_Google']= (df_clean['SPEC_virtual assistant'] == 'Google').astype(int)
df_clean['SPEC_virtualassist_Siri']= (df_clean['SPEC_virtual assistant'] == 'Siri').astype(int)
df_clean['SPEC_virtualassist_other']= (df_clean['SPEC_virtual assistant'] == 'other').astype(int)
df_clean['SPEC_Connectivity_SIM']= (df_clean['SPEC_connection type'] == 'Via SIM in vehicle').astype(int)
df_clean['SPEC_Connectivity_phone']= (df_clean['SPEC_connection type'] == 'Via own phone').astype(int)
df_clean['SPEC_parkingassist_disponly'] = \
    ((df_clean['SPEC_type192'] == 'guidance display')|(df_clean['SPEC_type192'] == ' :guidance display')).astype(int)
df_clean['SPEC_parkingassist_semiauto'] = df_clean['SPEC_type192'].str.contains('semi-auto').fillna(False).astype(int)
df_clean['SPEC_parkingassist_auto'] = df_clean['SPEC_type192'].str.contains('full auto').fillna(False).astype(int)
df_clean['SPEC_parkingassist_remote'] = df_clean['SPEC_type192'].str.contains('remote').fillna(False).astype(int)

df_clean['SPEC_autobrakeforparking'] = df_clean["SPEC_automatic braking whilst parking"].apply(lambda x:
    1 if (x == '1') or (x == '0:1') or (x == ' :1') or (x == '1:0') else 0).fillna(0)
df_clean['SPEC_cargodoor_RR'] = (df_clean['SPEC_location237'] == 'rear').astype(int)
df_clean['SPEC_cargodoor_PSGRR'] = (df_clean['SPEC_location237'] == 'passenger:rear').astype(int)
df_clean['SPEC_cargodoor_DRPSGRR'] = (df_clean['SPEC_location237'] == 'driver:passenger:rear').astype(int)
df_clean['SPEC_extdoorhundle_black'] = (df_clean['SPEC_color244'] == 'black').astype(int)
df_clean['SPEC_extdoorhundle_chrome'] = (df_clean['SPEC_color244'] == 'chrome').astype(int)
df_clean['SPEC_extdoorhundle_2tone'] = (df_clean['SPEC_color244'] == '2-tone').astype(int)
df_clean['SPEC_reardoor_liftinggate'] = (df_clean['SPEC_type246'] == 'lifting gate').astype(int)
df_clean['SPEC_reardoor_doublehinged'] = (df_clean['SPEC_type246'] == 'double hinged').astype(int)
df_clean['SPEC_reardoor_splitgate'] = (df_clean['SPEC_type246'] == 'split gate').astype(int)
df_clean['SPEC_reardoor_singlehinged'] = (df_clean['SPEC_type246'] == 'single hinged').astype(int)
df_clean['SPEC_configuration_V'] = (df_clean['SPEC_configuration'] == 'V').astype(int)
df_clean['SPEC_configuration_inline'] = (df_clean['SPEC_configuration'] == 'in-line').astype(int)
df_clean['SPEC_configuration_horizontal'] = (df_clean['SPEC_configuration'] == 'horizontal').astype(int)
df_clean['SPEC_valvegear_doubleoverheadcam'] = (df_clean['SPEC_valve gear type'] == 'double overhead cam').astype(int)
df_clean['SPEC_valvegear_singleoverheadcam'] = (df_clean['SPEC_valve gear type'] == 'overhead cam').astype(int)
df_clean['SPEC_valvegear_overheadvalve'] = (df_clean['SPEC_valve gear type'] == 'overhead valve').astype(int)
df_clean['SPEC_Compressor_turbo'] = (df_clean['SPEC_Compressor257'] == 'turbo').astype(int)
df_clean['SPEC_Compressor_supercharger'] = (df_clean['SPEC_Compressor257'] == 'supercharger').astype(int)
df_clean['SPEC_electricalsystem'] = (df_clean['SPEC_Electrical system'] == 'standard').astype(int)
df_clean['SPEC_electricalsystem'] = (df_clean['SPEC_Electrical system'] == 'standard').astype(int)
df_clean['SPEC_motorpowerhpPS_total'] = df_clean["SPEC_power output motor hp/PS"].apply(lambda x:\
    sum([float(i) for i in str(x).split(':') if i !=' '])
    ).fillna(0).astype(int)
df_clean['SPEC_motorpowerkW_total'] = df_clean["SPEC_power output motor kW"].apply(lambda x:\
    sum([float(i) for i in str(x).split(':') if i !=' '])
    ).fillna(0).astype(int)
df_clean['SPEC_motortorquelbft_max'] = df_clean["SPEC_max torque motor lb ft"].apply(lambda x:\
    max([float(i) for i in str(x).split(':') if i !=' '])
    ).fillna(0).astype(int)
df_clean['SPEC_motortorqueNm_max'] = df_clean["SPEC_max torque motor Nm"].apply(lambda x:\
    max([float(i) for i in str(x).split(':') if i !=' '])
    ).fillna(0).astype(int)
df_clean['SPEC_numchargingcable'] = df_clean["SPEC_charging cable included"].apply(lambda x:\
    sum([float(i) for i in str(x).split(':') if i !=' '])
    ).fillna(0).astype(int)

df_clean['SPEC_DC1socket'] = ~df_clean["SPEC_charging socket DC 1"].isna()
df_clean['SPEC_AC1socket'] = ~df_clean["SPEC_charging socket AC 1"].isna()
df_clean['SPEC_HeadUpDisplay'] = ((df_clean['SPEC_head-up display'] == 'windscreen')\
                                |(df_clean['SPEC_head-up display'] == '1')\
                                |(df_clean['SPEC_head-up display'] == 'panel')).astype(int)

df_clean['SPEC_luxurytrim_shiftknob_alloy'] = df_clean['SPEC_on shift knob'].str.contains('alloy').fillna(False).astype(int)
df_clean['SPEC_luxurytrim_shiftknob_leather'] = df_clean['SPEC_on shift knob'].str.contains('leather').fillna(False).astype(int)
df_clean['SPEC_luxurytrim_shiftknob_chrome'] = df_clean['SPEC_on shift knob'].str.contains('chrome').fillna(False).astype(int)
df_clean['SPEC_luxurytrim_shiftknob_gloss'] = df_clean['SPEC_on shift knob'].str.contains('gloss').fillna(False).astype(int)
df_clean['SPEC_luxurytrim_shiftknob_wood'] = df_clean['SPEC_on shift knob'].str.contains('wood').fillna(False).astype(int)
df_clean['SPEC_luxurytrim_centerconsole_alloy'] = df_clean['SPEC_on center floor console'].str.contains('alloy').fillna(False).astype(int)
df_clean['SPEC_luxurytrim_centerconsole_leather'] = df_clean['SPEC_on center floor console'].str.contains('^(?!.*synthetic leather).*leather', regex=True).fillna(False).astype(int)
df_clean['SPEC_luxurytrim_centerconsole_syntheticleather'] = df_clean['SPEC_on center floor console'].str.contains('synthetic leather').fillna(False).astype(int)
df_clean['SPEC_luxurytrim_centerconsole_gloss'] = df_clean['SPEC_on center floor console'].str.contains('gloss').fillna(False).astype(int)
df_clean['SPEC_luxurytrim_centerconsole_wood'] = df_clean['SPEC_on center floor console'].str.contains('wood').fillna(False).astype(int)
df_clean['SPEC_luxurytrim_centerconsole_suede'] = df_clean['SPEC_on center floor console'].str.contains('suede').fillna(False).astype(int)
df_clean['SPEC_luxurytrim_centerconsole_pianoblack'] = df_clean['SPEC_on center floor console'].str.contains('piano black').fillna(False).astype(int)
df_clean['SPEC_luxurytrim_centerconsole_carbon'] = df_clean['SPEC_on center floor console'].str.contains('carbon').fillna(False).astype(int)
df_clean['SPEC_luxurytrim_centerconsole_titanium'] = df_clean['SPEC_on center floor console'].str.contains('titanium').fillna(False).astype(int)

df_clean['SPEC_luxurytrim_door_alloy'] = df_clean['SPEC_on doors'].str.contains('alloy').fillna(False).astype(int)
df_clean['SPEC_luxurytrim_door_leather'] = df_clean['SPEC_on doors'].str.contains('^(?!.*synthetic leather).*leather', regex=True).fillna(False).astype(int)
df_clean['SPEC_luxurytrim_door_syntheticleather'] = df_clean['SPEC_on doors'].str.contains('synthetic leather').fillna(False).astype(int)
df_clean['SPEC_luxurytrim_door_gloss'] = df_clean['SPEC_on doors'].str.contains('gloss').fillna(False).astype(int)
df_clean['SPEC_luxurytrim_door_wood'] = df_clean['SPEC_on doors'].str.contains('wood').fillna(False).astype(int)
df_clean['SPEC_luxurytrim_door_suede'] = df_clean['SPEC_on doors'].str.contains('suede').fillna(False).astype(int)
df_clean['SPEC_luxurytrim_door_pianoblack'] = df_clean['SPEC_on doors'].str.contains('piano black').fillna(False).astype(int)
df_clean['SPEC_luxurytrim_door_carbon'] = df_clean['SPEC_on doors'].str.contains('carbon').fillna(False).astype(int)
df_clean['SPEC_luxurytrim_door_titanium'] = df_clean['SPEC_on doors'].str.contains('titanium').fillna(False).astype(int)

df_clean['SPEC_luxurytrim_instrumentpanel_alloy'] = df_clean['SPEC_on instrument panel'].str.contains('alloy').fillna(False).astype(int)
df_clean['SPEC_luxurytrim_instrumentpanel_leather'] = df_clean['SPEC_on instrument panel'].str.contains('^(?!.*synthetic leather).*leather', regex=True).fillna(False).astype(int)
df_clean['SPEC_luxurytrim_instrumentpanel_syntheticleather'] = df_clean['SPEC_on instrument panel'].str.contains('synthetic leather').fillna(False).astype(int)
df_clean['SPEC_luxurytrim_instrumentpanel_gloss'] = df_clean['SPEC_on instrument panel'].str.contains('gloss').fillna(False).astype(int)
df_clean['SPEC_luxurytrim_instrumentpanel_wood'] = df_clean['SPEC_on instrument panel'].str.contains('wood').fillna(False).astype(int)
df_clean['SPEC_luxurytrim_instrumentpanel_suede'] = df_clean['SPEC_on instrument panel'].str.contains('suede').fillna(False).astype(int)
df_clean['SPEC_luxurytrim_instrumentpanel_pianoblack'] = df_clean['SPEC_on instrument panel'].str.contains('piano black').fillna(False).astype(int)
df_clean['SPEC_luxurytrim_instrumentpanel_carbon'] = df_clean['SPEC_on instrument panel'].str.contains('carbon').fillna(False).astype(int)
df_clean['SPEC_luxurytrim_instrumentpanel_titanium'] = df_clean['SPEC_on instrument panel'].str.contains('titanium').fillna(False).astype(int)
df_clean['SPEC_luxurytrim_instrumentpanel_chrome'] = df_clean['SPEC_on instrument panel'].str.contains('chrome').fillna(False).astype(int)

df_clean['SPEC_luxurytrim_handbrakegrip_leather'] = (df_clean['SPEC_on handbrake grip']=='leather').fillna(False).astype(int)
df_clean['SPEC_luxurytrim_handbrakegrip_alloy'] = (df_clean['SPEC_on handbrake grip']=='alloy or alloy look').fillna(False).astype(int)

df_clean['SPEC_removablecargomat_textile'] = (df_clean['SPEC_removable cargo mat']=='textile').fillna(False).astype(int)
df_clean['SPEC_removablecargomat_plasticrubber'] = (df_clean['SPEC_removable cargo mat']=='plastic/rubber').fillna(False).astype(int)

df_clean['SPEC_headlight_Xenon'] = ((df_clean['SPEC_bulb type (low beam)'] == 'Bi-Xenon')|(df_clean['SPEC_bulb type (low beam)'] == 'Xenon')).fillna(False).astype(int)
df_clean['SPEC_headlight_Halogen'] = (df_clean['SPEC_bulb type (low beam)'] == 'halogen').fillna(False).astype(int)

df_clean['SPEC_LED_sideindicator'] = df_clean['SPEC_location380'].str.contains('side indicator lights').fillna(False).astype(int)
df_clean['SPEC_LED_lowbeam'] = df_clean['SPEC_location380'].str.contains('low beam').fillna(False).astype(int)
df_clean['SPEC_LED_breaklight'] = df_clean['SPEC_location380'].str.contains('brake lights').fillna(False).astype(int)
df_clean['SPEC_LED_rearlight'] = df_clean['SPEC_location380'].str.contains('rear lights').fillna(False).astype(int)
df_clean['SPEC_LED_DTRL'] = df_clean['SPEC_location380'].str.contains('day time running lights').fillna(False).astype(int)
df_clean['SPEC_LED_highbeam'] = df_clean['SPEC_location380'].str.contains('high beam').fillna(False).astype(int)
df_clean['SPEC_LED_FRFog'] = df_clean['SPEC_location380'].str.contains('front fog lights').fillna(False).astype(int)

df_clean['SPEC_Basepainttype_metallic'] = (df_clean['SPEC_type396'] == 'metallic').fillna(False).astype(int)
df_clean['SPEC_Basepainttype_pearl'] = (df_clean['SPEC_type396'] == 'pearl').fillna(False).astype(int)
df_clean['SPEC_Basepainttype_black'] = (df_clean['SPEC_type396'] == 'black').fillna(False).astype(int)
df_clean['SPEC_Basepainttype_mica'] = (df_clean['SPEC_type396'] == 'mica').fillna(False).astype(int)
df_clean['SPEC_Basepainttype_gloss'] = (df_clean['SPEC_type396'] == 'gloss').fillna(False).astype(int)

df_clean['SPEC_Sunroof_electric'] = ((df_clean['SPEC_operation702'] == 'electric')|(df_clean['SPEC_operation702'] == 'electric:removable')).fillna(False).astype(int)
df_clean['SPEC_Sunroof_remote'] = (df_clean['SPEC_operation702'] == 'remote').fillna(False).astype(int)

df_clean['SPEC_Roofrail_crossbars'] = ((df_clean['SPEC_cross bars'] == 'fixed')|(df_clean['SPEC_cross bars'] == 'removable')).fillna(False).astype(int)

df_clean['SPEC_Convertibleroof_soft'] = (df_clean['SPEC_type706'] == 'soft').fillna(False).astype(int)
df_clean['SPEC_Convertibleroof_hard'] = ((df_clean['SPEC_type706'] == 'hard')|(df_clean['SPEC_type706'] == 'hard:soft')).fillna(False).astype(int)
df_clean['SPEC_Convertibleroof_foldable'] = ((df_clean['SPEC_type706'] == 'soft:foldable hard top')|(df_clean['SPEC_type706'] == 'foldable hard top')).fillna(False).astype(int)
df_clean['SPEC_Convertibleroof_glassRRwindow'] = (df_clean['SPEC_glass rear window'] == 'yes').fillna(False).astype(int)
df_clean['SPEC_Convertibleroof_electric'] = ((df_clean['SPEC_operation707'] == 'electric')|(df_clean['SPEC_operation707'] == 'electric:remote')).fillna(False).astype(int)
df_clean['SPEC_Convertibleroof_remote'] = (df_clean['SPEC_operation707'] == 'remote').fillna(False).astype(int)
df_clean['SPEC_Convertibleroof_remote'] = (df_clean['SPEC_operation707'] == 'remote').fillna(False).astype(int)
df_clean['SPEC_ConvRolloverprotection_concealed'] = (df_clean['SPEC_type709'] == 'concealed system').fillna(False).astype(int)
df_clean['SPEC_ConvRolloverprotection_fixedhoop'] = (df_clean['SPEC_type709'] == 'fixed hoop').fillna(False).astype(int)

df_clean['SPEC_FRAirbag_switchoff'] = (df_clean['SPEC_occupant switch off'] == ' :yes').fillna(False).astype(int)
df_clean['SPEC_FRAirbag_intelligent'] = ((df_clean['SPEC_intelligent'] == '1')|(df_clean['SPEC_intelligent'] == '0:1')).fillna(False).astype(int)

df_clean['SPEC_SideAirbag_FR'] = df_clean['SPEC_location722'].str.contains('front').fillna(False).astype(int)
df_clean['SPEC_SideAirbag_RR'] = df_clean['SPEC_location722'].str.contains('rear').fillna(False).astype(int)
df_clean['SPEC_SideAirbag_headprotect'] = ((df_clean['SPEC_head protection'] == '1')|(df_clean['SPEC_head protection'] == '1:')).fillna(False).astype(int)

df_clean['SPEC_CurtainAirbag_numRows'] = df_clean['SPEC_location724'].apply(lambda x:
    1 if x == 'front'
    else 2 if x == 'front and rear'
    else 3 if x == 'all three rows'
    else 4 if x == 'all four rows'
    else 5 if x == 'all five rows'
    else 0
)

df_clean['SPEC_KneeAirbag_driver'] = df_clean['SPEC_location726'].str.contains('driver').fillna(False).astype(int)
df_clean['SPEC_KneeAirbag_passenger'] = df_clean['SPEC_location726'].str.contains('passenger').fillna(False).astype(int)

df_clean['SPEC_headrestraints_numrows'] = df_clean['SPEC_location728'].apply(lambda x:
    1 if (x == 'front')|(x == 'front seats')
    else 2 if (x == 'front seats:rear seats')|(x == 'front:rear')
    else 3 if x == 'front seats:rear seats:3rd row seats'
    else 4 if x == 'front seats:rear seats:3rd row seats:4th row seats'
    else 5 if x == 'front seats:rear seats:3rd row seats:4th row seats:5th row seats'
    else 0
)

df_clean['SPEC_headrestraints_heightadjust'] = df_clean['SPEC_height adjustable'].str.contains('1').fillna(False).astype(int)
df_clean['SPEC_headrestraints_electricadjust'] = df_clean['SPEC_electric adjustable'].str.contains('yes').fillna(False).astype(int)
df_clean['SPEC_headrestraints_active'] = df_clean['SPEC_active'].str.contains('1').fillna(False).astype(int)
df_clean['SPEC_headrestraints_num'] = df_clean["SPEC_charging cable included"].apply(lambda x:\
    sum([float(i) for i in str(x).split(':') if i !=' '])).fillna(0).astype(int)

df_clean['SPEC_FRseatbelt_DRPG'] = df_clean['SPEC_seat position'].str.contains('driver:passenger').fillna(False).astype(int)
df_clean['SPEC_FRseatbelt_Center'] = df_clean['SPEC_seat position'].str.contains('driver:passenger:center').fillna(False).astype(int)
df_clean['SPEC_FRseatbelt_pretentioners'] = df_clean['SPEC_pre-tensioners'].str.contains('1').fillna(False).astype(int)
df_clean['SPEC_FRseatbelt_heightadjust'] = df_clean['SPEC_height adjustable738'].str.contains('1').fillna(False).astype(int)
df_clean['SPEC_FRseatbelt_extenders'] = df_clean['SPEC_extenders'].str.contains('1').fillna(False).astype(int)

df_clean['SPEC_RRseatbelt_DRPG'] = df_clean['SPEC_seat position740'].str.contains('driver:passenger').fillna(False).astype(int)
df_clean['SPEC_RRseatbelt_DRPGCenter'] = df_clean['SPEC_seat position740'].str.contains('driver:passenger:center').fillna(False).astype(int)
df_clean['SPEC_RRseatbelt_center3point'] = df_clean['SPEC_type741'].str.contains(' : :3-point').fillna(False).astype(int)
df_clean['SPEC_RRseatbelt_centerreel'] = df_clean['SPEC_operation742'].str.contains(' : :reel').fillna(False).astype(int)
df_clean['SPEC_RRseatbelt_pretentioners'] = df_clean["SPEC_pre-tensioners743"].apply(lambda x:\
    max([float(i) for i in str(x).split(':') if i !=' '])).fillna(0).astype(int)
df_clean['SPEC_RRseatbelt_heightadjust'] = df_clean["SPEC_height adjustable744"].apply(lambda x:\
    max([float(i) for i in str(x).split(':') if i !=' '])).fillna(0).astype(int)

df_clean['SPEC_3rdrowseatbelt_DRPG'] = df_clean["SPEC_seat position746"].str.contains('driver:passenger').fillna(False).astype(int)
df_clean['SPEC_3rdrowseatbelt_Center'] = df_clean["SPEC_seat position746"].str.contains('driver:passenger:center').fillna(False).astype(int)
df_clean['SPEC_3rdrowseatbelt_Center3point'] = df_clean["SPEC_type747"].str.contains(' : :3-point').fillna(False).astype(int)
df_clean['SPEC_3rdrowseatbelt_centerreel'] = df_clean['SPEC_operation748'].str.contains(' : :reel').fillna(False).astype(int)

df_clean['SPEC_AutomaticEmergencyBrake_lowspeed_front'] = df_clean['SPEC_brakes at low speed'].str.contains('front').fillna(False).astype(int)
df_clean['SPEC_AutomaticEmergencyBrake_lowspeed_rear'] = df_clean['SPEC_brakes at low speed'].str.contains('rear').fillna(False).astype(int)

df_clean['SPEC_AutonomousDriving_level1'] = (df_clean['SPEC_level'] == '1 - driver assistance').fillna(False).astype(int)
df_clean['SPEC_AutonomousDriving_level2'] = (df_clean['SPEC_level'] == '2 - partial automation').fillna(False).astype(int)
df_clean['SPEC_AutonomousDriving_level3'] = (df_clean['SPEC_level'] == '3 - conditional automation').fillna(False).astype(int)

df_clean['SPEC_NHTSA_sideimpact_5'] = df_clean['SPEC_side impact'].str.contains('5').fillna(False).astype(int)
df_clean['SPEC_NHTSA_sideimpact_4'] = df_clean['SPEC_side impact'].str.contains('4').fillna(False).astype(int)
df_clean['SPEC_NHTSA_sideimpact_3'] = df_clean['SPEC_side impact'].str.contains('3').fillna(False).astype(int)
df_clean['SPEC_NHTSA_sideimpact_2'] = df_clean['SPEC_side impact'].str.contains('2').fillna(False).astype(int)
df_clean['SPEC_NHTSA_sideimpact_1'] = df_clean['SPEC_side impact'].str.contains('1').fillna(False).astype(int)

df_clean['SPEC_NHTSA_rollover_5'] = df_clean['SPEC_rollover rating'].str.contains('5').fillna(False).astype(int)
df_clean['SPEC_NHTSA_rollover_4'] = df_clean['SPEC_rollover rating'].str.contains('4').fillna(False).astype(int)
df_clean['SPEC_NHTSA_rollover_3'] = df_clean['SPEC_rollover rating'].str.contains('3').fillna(False).astype(int)
df_clean['SPEC_NHTSA_rollover_2'] = df_clean['SPEC_rollover rating'].str.contains('2').fillna(False).astype(int)
df_clean['SPEC_NHTSA_rollover_1'] = df_clean['SPEC_rollover rating'].str.contains('1').fillna(False).astype(int)

df_clean['SPEC_NHTSA_overall_5'] = df_clean['SPEC_overall'].str.contains('5').fillna(False).astype(int)
df_clean['SPEC_NHTSA_overall_4'] = df_clean['SPEC_overall'].str.contains('4').fillna(False).astype(int)
df_clean['SPEC_NHTSA_overall_3'] = df_clean['SPEC_overall'].str.contains('3').fillna(False).astype(int)
df_clean['SPEC_NHTSA_overall_2'] = df_clean['SPEC_overall'].str.contains('2').fillna(False).astype(int)
df_clean['SPEC_NHTSA_overall_1'] = df_clean['SPEC_overall'].str.contains('1').fillna(False).astype(int)

df_clean['SPEC_NHTSA_frontcrash_5'] = df_clean['SPEC_frontal crash rating'].str.contains('5').fillna(False).astype(int)
df_clean['SPEC_NHTSA_frontcrash_4'] = df_clean['SPEC_frontal crash rating'].str.contains('4').fillna(False).astype(int)
df_clean['SPEC_NHTSA_frontcrash_3'] = df_clean['SPEC_frontal crash rating'].str.contains('3').fillna(False).astype(int)
df_clean['SPEC_NHTSA_frontcrash_2'] = df_clean['SPEC_frontal crash rating'].str.contains('2').fillna(False).astype(int)
df_clean['SPEC_NHTSA_frontcrash_1'] = df_clean['SPEC_frontal crash rating'].str.contains('1').fillna(False).astype(int)

df_clean['SPEC_IIHS_sideimpact_Good'] = df_clean['SPEC_side impact'].str.contains('Good').fillna(False).astype(int)
df_clean['SPEC_IIHS_sideimpact_Acceptable'] = df_clean['SPEC_side impact'].str.contains('Acceptable').fillna(False).astype(int)
df_clean['SPEC_IIHS_sideimpact_Marginal'] = df_clean['SPEC_side impact'].str.contains('Marginal').fillna(False).astype(int)
df_clean['SPEC_IIHS_sideimpact_Poor'] = df_clean['SPEC_side impact'].str.contains('Poor').fillna(False).astype(int)

df_clean['SPEC_IIHS_moderateoverlap_Good'] = df_clean['SPEC_moderate overlap front test'].str.contains('Good').fillna(False).astype(int)
df_clean['SPEC_IIHS_moderateoverlap_Acceptable'] = df_clean['SPEC_moderate overlap front test'].str.contains('Acceptable').fillna(False).astype(int)
df_clean['SPEC_IIHS_moderateoverlap_Marginal'] = df_clean['SPEC_moderate overlap front test'].str.contains('Marginal').fillna(False).astype(int)
df_clean['SPEC_IIHS_moderateoverlap_Poor'] = df_clean['SPEC_moderate overlap front test'].str.contains('Poor').fillna(False).astype(int)

df_clean['SPEC_IIHS_smalloverlapFRDR_Good'] = df_clean['SPEC_small overlap front - driver'].str.contains('Good').fillna(False).astype(int)
df_clean['SPEC_IIHS_smalloverlapFRDR_Acceptable'] = df_clean['SPEC_small overlap front - driver'].str.contains('Acceptable').fillna(False).astype(int)
df_clean['SPEC_IIHS_smalloverlapFRDR_Marginal'] = df_clean['SPEC_small overlap front - driver'].str.contains('Marginal').fillna(False).astype(int)
df_clean['SPEC_IIHS_smalloverlapFRDR_Poor'] = df_clean['SPEC_small overlap front - driver'].str.contains('Poor').fillna(False).astype(int)

df_clean['SPEC_IIHS_smalloverlapFRPG_Good'] = df_clean['SPEC_small overlap front - passenger'].str.contains('Good').fillna(False).astype(int)
df_clean['SPEC_IIHS_smalloverlapFRPG_Acceptable'] = df_clean['SPEC_small overlap front - passenger'].str.contains('Acceptable').fillna(False).astype(int)
df_clean['SPEC_IIHS_smalloverlapFRPG_Marginal'] = df_clean['SPEC_small overlap front - passenger'].str.contains('Marginal').fillna(False).astype(int)
df_clean['SPEC_IIHS_smalloverlapFRPG_Poor'] = df_clean['SPEC_small overlap front - passenger'].str.contains('Poor').fillna(False).astype(int)

df_clean['SPEC_IIHS_roofstrength_Good'] = df_clean['SPEC_roof strength test'].str.contains('Good').fillna(False).astype(int)
df_clean['SPEC_IIHS_roofstrength_Acceptable'] = df_clean['SPEC_roof strength test'].str.contains('Acceptable').fillna(False).astype(int)
df_clean['SPEC_IIHS_roofstrength_Marginal'] = df_clean['SPEC_roof strength test'].str.contains('Marginal').fillna(False).astype(int)
df_clean['SPEC_IIHS_roofstrength_Poor'] = df_clean['SPEC_roof strength test'].str.contains('Poor').fillna(False).astype(int)

df_clean['SPEC_IIHS_RRcrashprotectHeadrestraint_Good'] = df_clean['SPEC_rear crash protect/head restraint rating'].str.contains('Good').fillna(False).astype(int)
df_clean['SPEC_IIHS_RRcrashprotectHeadrestraint_Acceptable'] = df_clean['SPEC_rear crash protect/head restraint rating'].str.contains('Acceptable').fillna(False).astype(int)
df_clean['SPEC_IIHS_RRcrashprotectHeadrestraint_Marginal'] = df_clean['SPEC_rear crash protect/head restraint rating'].str.contains('Marginal').fillna(False).astype(int)
df_clean['SPEC_IIHS_RRcrashprotectHeadrestraint_Poor'] = df_clean['SPEC_rear crash protect/head restraint rating'].str.contains('Poor').fillna(False).astype(int)

df_clean['SPEC_IIHS_TopSafetyPick'] = ((df_clean['SPEC_top Safety Pick status'] == 'TSP: ')|(df_clean['SPEC_top Safety Pick status'] == 'TSP')).fillna(False).astype(int)
df_clean['SPEC_IIHS_TopSafetyPick'] = ((df_clean['SPEC_top Safety Pick status'] == 'TSP Plus: ')|(df_clean['SPEC_top Safety Pick status'] == 'TSP Plus')).fillna(False).astype(int)

df_clean['SPEC_Seat_num'] = df_clean["SPEC_charging cable included"].apply(lambda x:\
    sum([float(i) for i in str(x).split(':') if i !=' '])
    ).fillna(0).astype(int)

df_clean['SPEC_FRseat_captain'] = (df_clean['SPEC_type808'] == "captain's").fillna(False).astype(int)

temp_lst = ['manual', 'manual:electric','manual:manual: ',  'manual:electric: ']
df_clean['SPEC_FRDRseat_reclining_manual'] = (df_clean['SPEC_reclining type'].isin(temp_lst)).fillna(False).astype(int)
temp_lst = ['manual', 'electric:manual', 'memory:manual', 'manual:manual: ', 'electric:manual: ', '-:manual', 'memory:manual: ']
df_clean['SPEC_FRPGseat_reclining_manual'] = (df_clean['SPEC_reclining type'].isin(temp_lst)).fillna(False).astype(int)
temp_lst = ['electric', 'electric: ', 'electric:manual', 'electric:manual: ', 'electric:electric: ']
df_clean['SPEC_FRDRseat_reclining_electric'] = (df_clean['SPEC_reclining type'].isin(temp_lst)).fillna(False).astype(int)
temp_lst = ['memory:electric', 'electric',  'manual:electric', 'memory:electric: ',  'electric:electric: ', 'manual:electric: ']
df_clean['SPEC_FRPGseat_reclining_electric'] = (df_clean['SPEC_reclining type'].isin(temp_lst)).fillna(False).astype(int)
temp_lst = ['memory:electric', 'memory', 'memory:manual', 'memory:electric: ', 'memory:manual: ']
df_clean['SPEC_FRDRseat_reclining_memory'] = (df_clean['SPEC_reclining type'].isin(temp_lst)).fillna(False).astype(int)
temp_lst = ['memory']
df_clean['SPEC_FRPGseat_reclining_memory'] = (df_clean['SPEC_reclining type'].isin(temp_lst)).fillna(False).astype(int)

# Reach = slide
temp_lst = ['manual', 'manual:manual: ', 'manual:-', 'manual:memory']
df_clean['SPEC_FRDRseat_reach_manual'] = (df_clean['SPEC_reach type'].isin(temp_lst)).fillna(False).astype(int)
temp_lst = ['manual', 'electric:manual', 'memory:manual', 'manual:manual: ', 'electric:manual: ']
df_clean['SPEC_FRPGseat_reach_manual'] = (df_clean['SPEC_reach type'].isin(temp_lst)).fillna(False).astype(int)
temp_lst = ['electric', 'electric: ', 'electric:manual', 'electric:manual: ', 'electric:electric: ']
df_clean['SPEC_FRDRseat_reach_electric'] = (df_clean['SPEC_reach type'].isin(temp_lst)).fillna(False).astype(int)
temp_lst = ['memory:electric', 'electric','memory:electric: ', 'electric:electric: ']
df_clean['SPEC_FRPGseat_reach_electric'] = (df_clean['SPEC_reach type'].isin(temp_lst)).fillna(False).astype(int)
temp_lst = ['memory:electric', 'memory', 'memory:manual', 'memory:electric: ']
df_clean['SPEC_FRDRseat_reach_memory'] = (df_clean['SPEC_reach type'].isin(temp_lst)).fillna(False).astype(int)
temp_lst = [ 'memory', 'manual:memory']
df_clean['SPEC_FRPGseat_reach_memory'] = (df_clean['SPEC_reach type'].isin(temp_lst)).fillna(False).astype(int)

temp_lst = ['manual', 'manual:-']
df_clean['SPEC_FRDRseat_height_manual'] = (df_clean['SPEC_height type'].isin(temp_lst)).fillna(False).astype(int)
temp_lst = ['manual', 'electric:manual', 'memory:manual']
df_clean['SPEC_FRPGseat_height_manual'] = (df_clean['SPEC_height type'].isin(temp_lst)).fillna(False).astype(int)
temp_lst = ['electric', 'electric: ', 'electric:-', 'electric:manual', 'electric:-:-', 'electric:electric:-']
df_clean['SPEC_FRDRseat_height_electric'] = (df_clean['SPEC_height type'].isin(temp_lst)).fillna(False).astype(int)
temp_lst = ['memory:electric', 'electric', 'memory:electric:-', 'electric:electric:-']
df_clean['SPEC_FRPGseat_height_electric'] = (df_clean['SPEC_height type'].isin(temp_lst)).fillna(False).astype(int)
temp_lst = ['memory:electric', 'memory:-', 'memory', 'memory:electric:-', 'memory:manual']
df_clean['SPEC_FRDRseat_height_memory'] = (df_clean['SPEC_height type'].isin(temp_lst)).fillna(False).astype(int)
temp_lst = ['memory']
df_clean['SPEC_FRPGseat_height_memory'] = (df_clean['SPEC_height type'].isin(temp_lst)).fillna(False).astype(int)

temp_lst = ['manual', 'manual:-:-', 'manual:manual:-', 'manual:-',  '2-way manual']
df_clean['SPEC_FRDRseat_lumbar_manual'] = (df_clean['SPEC_lumbar type'].isin(temp_lst)).fillna(False).astype(int)
temp_lst = ['manual', 'manual:manual:-', 'electric:manual', 'memory:manual', 'electric:manual:-', '2-way manual']
df_clean['SPEC_FRPGseat_lumbar_manual'] = (df_clean['SPEC_lumbar type'].isin(temp_lst)).fillna(False).astype(int)
temp_lst = ['electric:-', 'electric', '2-way electric', '2-way electric:electric', '2-way electric:-', '2-way electric: ', 'electric:electric:-', 'electric:-:-', 'electric:manual',  'electric:manual:-', 'electric: ', 'electric:memory', '2-way electric:2-way electric:-']
df_clean['SPEC_FRDRseat_lumbar_electric'] = (df_clean['SPEC_lumbar type'].isin(temp_lst)).fillna(False).astype(int)
temp_lst = [ 'electric', '2-way electric', '2-way electric:electric',  'memory:electric', '2-way memory:2-way electric', 'electric:electric:-',   '2-way memory:electric',  'memory:electric:-', 'memory:2-way electric', '2-way electric:2-way electric:-']
df_clean['SPEC_FRPGseat_lumbar_electric'] = (df_clean['SPEC_lumbar type'].isin(temp_lst)).fillna(False).astype(int)
temp_lst = ['memory:electric', '2-way memory:2-way electric', '2-way memory:-', '2-way memory', 'memory:-', 'memory:manual', '2-way memory:electric', 'memory:electric:-', 'memory:2-way electric', '2-way memory:memory', 'memory: ']
df_clean['SPEC_FRDRseat_lumbar_memory'] = (df_clean['SPEC_lumbar type'].isin(temp_lst)).fillna(False).astype(int)
temp_lst = [ '2-way memory',  '2-way memory:memory',  'electric:memory']
df_clean['SPEC_FRPGseat_lumbar_memory'] = (df_clean['SPEC_lumbar type'].isin(temp_lst)).fillna(False).astype(int)
temp_lst = ['2-way electric', '2-way electric:electric', '2-way electric:-', '2-way electric: ', '2-way memory:2-way electric', '2-way memory:-', '2-way memory', '2-way memory:electric', '2-way memory:memory', '2-way electric:2-way electric:-', '2-way manual']
df_clean['SPEC_FRDRseat_lumbar_2way'] = (df_clean['SPEC_lumbar type'].isin(temp_lst)).fillna(False).astype(int)
temp_lst = ['2-way electric',  '2-way memory:2-way electric', '2-way memory',  'memory:2-way electric', '2-way electric:2-way electric:-', '2-way manual']
df_clean['SPEC_FRPGseat_lumbar_2way'] = (df_clean['SPEC_lumbar type'].isin(temp_lst)).fillna(False).astype(int)

temp_lst = ['manual', 'manual:-']
df_clean['SPEC_FRDRseat_tilt_manual'] = (df_clean['SPEC_tilt type'].isin(temp_lst)).fillna(False).astype(int)
temp_lst = ['manual', 'electric:manual', ' :manual']
df_clean['SPEC_FRPGseat_tilt_manual'] = (df_clean['SPEC_tilt type'].isin(temp_lst)).fillna(False).astype(int)
temp_lst = ['electric', 'electric: ', 'electric:-', 'electric:-:-', 'electric:electric:-', 'electric:manual']
df_clean['SPEC_FRDRseat_tilt_electric'] = (df_clean['SPEC_tilt type'].isin(temp_lst)).fillna(False).astype(int)
temp_lst = ['memory:electric', 'electric', 'memory:electric:-','electric:electric:-',  ' :electric']
df_clean['SPEC_FRPGseat_tilt_electric'] = (df_clean['SPEC_tilt type'].isin(temp_lst)).fillna(False).astype(int)
temp_lst = ['memory:electric', 'memory:-', 'memory', 'memory:electric:-', 'memory: ']
df_clean['SPEC_FRDRseat_tilt_memory'] = (df_clean['SPEC_tilt type'].isin(temp_lst)).fillna(False).astype(int)
temp_lst = ['memory']
df_clean['SPEC_FRPGseat_tilt_memory'] = (df_clean['SPEC_tilt type'].isin(temp_lst)).fillna(False).astype(int)

temp_lst = ['manual','manual:-']
df_clean['SPEC_FRDRseat_thighsupport_manual'] = (df_clean['SPEC_thigh support type'].isin(temp_lst)).fillna(False).astype(int)
temp_lst = ['manual', '-:manual', 'memory:manual']
df_clean['SPEC_FRPGseat_thighsupport_manual'] = (df_clean['SPEC_thigh support type'].isin(temp_lst)).fillna(False).astype(int)
temp_lst = ['electric', 'electric:-']
df_clean['SPEC_FRDRseat_thighsupport_electric'] = (df_clean['SPEC_thigh support type'].isin(temp_lst)).fillna(False).astype(int)
temp_lst = ['electric',  'memory:electric']
df_clean['SPEC_FRPGseat_thighsupport_electric'] = (df_clean['SPEC_thigh support type'].isin(temp_lst)).fillna(False).astype(int)
temp_lst = ['memory', 'memory:electric', 'memory:-', 'memory: ', 'memory:manual']
df_clean['SPEC_FRDRseat_thighsupport_memory'] = (df_clean['SPEC_thigh support type'].isin(temp_lst)).fillna(False).astype(int)
temp_lst = ['memory']
df_clean['SPEC_FRPGseat_thighsupport_memory'] = (df_clean['SPEC_thigh support type'].isin(temp_lst)).fillna(False).astype(int)

temp_lst = ['1', '1:1:0', '1:0']
df_clean['SPEC_FRDRseat_heated'] = (df_clean['SPEC_heated'].isin(temp_lst)).fillna(False).astype(int)
temp_lst = ['1', '1:1:0', '0:1']
df_clean['SPEC_FRPGseat_heated'] = (df_clean['SPEC_heated'].isin(temp_lst)).fillna(False).astype(int)

temp_lst = ['1','1:0']
df_clean['SPEC_FRDRseat_massage'] = (df_clean['SPEC_active/massage'].isin(temp_lst)).fillna(False).astype(int)
temp_lst = ['1']
df_clean['SPEC_FRPGseat_massage'] = (df_clean['SPEC_active/massage'].isin(temp_lst)).fillna(False).astype(int)

temp_lst = ['1', '1:0', '1:1:0']
df_clean['SPEC_FRDRseat_ventilated'] = (df_clean['SPEC_ventilated'].isin(temp_lst)).fillna(False).astype(int)
temp_lst = ['1', '1:1:0','0:1']
df_clean['SPEC_FRPGseat_ventilated'] = (df_clean['SPEC_ventilated'].isin(temp_lst)).fillna(False).astype(int)

temp_lst = ['1',  '1:1:0', '1:0']
df_clean['SPEC_FRDRseat_climatecontroll'] = (df_clean['SPEC_climate controlled'].isin(temp_lst)).fillna(False).astype(int)
temp_lst = ['1','0:1', '1:1:0', ' :1']
df_clean['SPEC_FRPGseat_climatecontroll'] = (df_clean['SPEC_climate controlled'].isin(temp_lst)).fillna(False).astype(int)

temp_lst = [' :yes']
df_clean['SPEC_FRPGseat_folding'] = (df_clean['SPEC_folding809'].isin(temp_lst)).fillna(False).astype(int)

temp_lst = [' :yes']
df_clean['SPEC_FRPGseat_RRPGcontroll'] = (df_clean['SPEC_rear passenger control'].isin(temp_lst)).fillna(False).astype(int)

temp_lst = ['manual']
df_clean['SPEC_RRseat_reclining_manual'] = (df_clean['SPEC_reclining type814'].isin(temp_lst)).fillna(False).astype(int)

temp_lst = ['electric', 'memory']
df_clean['SPEC_RRseat_reclining_electric'] = (df_clean['SPEC_reclining type814'].isin(temp_lst)).fillna(False).astype(int)

temp_lst = ['manual']
df_clean['SPEC_RRseat_reach_manual'] = (df_clean['SPEC_reach type815'].isin(temp_lst)).fillna(False).astype(int)

temp_lst = ['electric', 'memory']
df_clean['SPEC_RRseat_reach_electric'] = (df_clean['SPEC_reach type815'].isin(temp_lst)).fillna(False).astype(int)

temp_lst = ['asymmetrical', 'symmetrical', '40/20/40', 'one-piece', 'individual']
df_clean['SPEC_RRseat_folding'] = (df_clean['SPEC_folding820'].isin(temp_lst)).fillna(False).astype(int)

df_clean['SPEC_Steering_alloy'] = df_clean['SPEC_type864'].str.contains('alloy').fillna(False).astype(int)
df_clean['SPEC_Steering_plastic'] = df_clean['SPEC_type864'].str.contains('plastic').fillna(False).astype(int)
df_clean['SPEC_Steering_leather'] = df_clean['SPEC_type864'].str.contains('^(?!.*synthetic leather).*leather', regex=True).fillna(False).astype(int)
df_clean['SPEC_Steering_syntheticleather'] = df_clean['SPEC_type864'].str.contains('synthetic leather').fillna(False).astype(int)
df_clean['SPEC_Steering_wood'] = df_clean['SPEC_type864'].str.contains('wood').fillna(False).astype(int)
df_clean['SPEC_Steering_suede'] = df_clean['SPEC_type864'].str.contains('suede').fillna(False).astype(int)

df_clean['SPEC_Console_dashboard'] = df_clean['SPEC_location882'].str.contains('dashboard').fillna(False).astype(int)
df_clean['SPEC_Console_floor'] = df_clean['SPEC_location882'].str.contains('floor').fillna(False).astype(int)
df_clean['SPEC_Console_overhead'] = df_clean['SPEC_location882'].str.contains('overhead').fillna(False).astype(int)
df_clean['SPEC_Console_other'] = df_clean.apply(lambda x:
                                    1 if pd.isnull(x['SPEC_location882']) & (x['SPEC_Console']==1)\
                                    else 0,\
                                    axis=1\
                                )
df_clean['SPEC_Cupholder_front'] = ((df_clean['SPEC_location890'].str.contains('front')).fillna(False)|\
                                (df_clean.apply(lambda x:\
                                    True if pd.isnull(x['SPEC_location890']) & (x['SPEC_Cup holders']==1)\
                                    else False,\
                                    axis=1\
                                ))).astype(int)
df_clean['SPEC_Cupholder_rear'] = df_clean['SPEC_location890'].str.contains('rear').fillna(False).astype(int)
df_clean['SPEC_Cupholder_3rdrow'] = df_clean['SPEC_location890'].str.contains('3rd').fillna(False).astype(int)

df_clean['SPEC_BelowseatStorage_rear'] = df_clean['SPEC_location895'].str.contains('rear').fillna(False).astype(int)
df_clean['SPEC_BelowseatStorage_passenger'] = df_clean['SPEC_location895'].str.contains('passenger').fillna(False).astype(int)
df_clean['SPEC_BelowseatStorage_driver'] = df_clean['SPEC_location895'].str.contains('driver').fillna(False).astype(int)

temp_lst = ['strut:multi-link', 'strut:wishbone', 'strut:torsion beam', 'strut:beam', 'strut']
df_clean['SPEC_FR_suspension_strut'] = (df_clean['SPEC_type905'].isin(temp_lst)).fillna(False).astype(int)
temp_lst = ['wishbone:strut', 'strut']
df_clean['SPEC_RR_suspension_strut'] = (df_clean['SPEC_type905'].isin(temp_lst)).fillna(False).astype(int)
temp_lst = ['multi-link']
df_clean['SPEC_FR_suspension_multilink'] = (df_clean['SPEC_type905'].isin(temp_lst)).fillna(False).astype(int)
temp_lst = ['strut:multi-link', 'wishbone:multi-link', 'multi-link']
df_clean['SPEC_RR_suspension_multilink'] = (df_clean['SPEC_type905'].isin(temp_lst)).fillna(False).astype(int)
temp_lst = ['wishbone:multi-link', 'wishbone', 'wishbone:beam','wishbone:trailing arm', 'wishbone:strut']
df_clean['SPEC_FR_suspension_wishbone'] = (df_clean['SPEC_type905'].isin(temp_lst)).fillna(False).astype(int)
temp_lst = [ 'wishbone','strut:wishbone']
df_clean['SPEC_RR_suspension_wishbone'] = (df_clean['SPEC_type905'].isin(temp_lst)).fillna(False).astype(int)
temp_lst = ['beam']
df_clean['SPEC_FR_suspension_beam'] = (df_clean['SPEC_type905'].isin(temp_lst)).fillna(False).astype(int)
temp_lst = ['wishbone:beam','strut:beam', 'other:beam', 'beam']
df_clean['SPEC_RR_suspension_beam'] = (df_clean['SPEC_type905'].isin(temp_lst)).fillna(False).astype(int)
temp_lst = ['strut:torsion beam']
df_clean['SPEC_RR_suspension_torsionbeam'] = (df_clean['SPEC_type905'].isin(temp_lst)).fillna(False).astype(int)
temp_lst = ['other:beam']
df_clean['SPEC_FR_suspension_torsionbeam'] = ((df_clean['SPEC_type905'].isin(temp_lst)).fillna(False)|\
                                (df_clean.apply(lambda x:\
                                    True if pd.isnull(x['SPEC_type905']) & (x['SPEC_Suspension902']=='standard')\
                                    else False,\
                                    axis=1\
                                ))).astype(int)

temp_lst = ['wishbone:trailing arm']
df_clean['SPEC_RR_suspension_torsionbeam'] = ((df_clean['SPEC_type905'].isin(temp_lst)).fillna(False)|\
                                (df_clean.apply(lambda x:\
                                    True if pd.isnull(x['SPEC_type905']) & (x['SPEC_Suspension902']=='standard')\
                                    else False,\
                                    axis=1\
                                ))).astype(int)

temp_lst = ['1', '1:0', '1: ']
df_clean['SPEC_FRsuspension_stabilizerbar'] = (df_clean['SPEC_type905'].isin(temp_lst)).fillna(False).astype(int)
temp_lst = ['1', '0:1']
df_clean['SPEC_RRsuspension_stabilizerbar'] = (df_clean['SPEC_type905'].isin(temp_lst)).fillna(False).astype(int)

df_clean['SPEC_suspentionleveling_rear'] = df_clean['SPEC_location907'].str.contains('rear').fillna(False).astype(int)
df_clean['SPEC_suspentionleveling_rear'] = df_clean['SPEC_location907'].str.contains('front').fillna(False).astype(int)

df_clean['SPEC_responsivesuspention_electric'] = ((df_clean['SPEC_type910'].str.contains('electronic').fillna(False).astype(int))|\
                                                (df_clean.apply(lambda x:\
                                                    True if pd.isnull(x['SPEC_type910']) & (x['SPEC_Responsive suspension']==1)\
                                                    else False,\
                                                    axis=1\
                                                ))).astype(int)
df_clean['SPEC_responsivesuspention_mechanical'] = df_clean['SPEC_type910'].str.contains('mechanical').fillna(False).astype(int)

df_clean['SPEC_transmission_AT'] = ((df_clean['SPEC_Transmission type915'].str.contains('automatic').fillna(False).astype(int))|\
                                                (df_clean.apply(lambda x:\
                                                    True if pd.isnull(x['SPEC_Transmission type915'])\
                                                    else False,\
                                                    axis=1\
                                                ))).astype(int)
df_clean['SPEC_transmission_MT'] = df_clean['SPEC_Transmission type915'].str.contains('manual').fillna(False).astype(int)

df_clean['SPEC_transmission_CVT'] = df_clean['SPEC_number of speeds'].str.contains('variable').fillna(False).astype(int)
df_clean['SPEC_transmission_numspeed'] = df_clean['SPEC_number of speeds'].fillna('1').astype(str).str.replace('variable', '6').astype(int)

df_clean['SPEC_4WD_fulltime'] = df_clean['SPEC_four wheel drive type'].str.contains('full').fillna(False).astype(int)
df_clean['SPEC_4WD_parttime'] = df_clean['SPEC_four wheel drive type'].str.contains('part').fillna(False).astype(int)
df_clean['SPEC_4WD_disconnect'] = df_clean['SPEC_four wheel drive type'].str.contains('disconnect').fillna(False).astype(int)

df_clean['SPEC_DescentControll_auto'] = df_clean['SPEC_selection'].str.contains('automatic').fillna(False).astype(int)
df_clean['SPEC_DescentControll_manual'] = df_clean['SPEC_selection'].str.contains('manual').fillna(False).astype(int)

df_clean['SPEC_Autoairconditioner_zones'] = df_clean['SPEC_climate control number of zones'].fillna('0').astype(str).str.replace('-', '0').astype(int)

temp_lst = ['electrically adjustable', 'electrically adjustable:externally adjustable', 'electrically adjustable: ']
df_clean['SPEC_doormirrorDRside_electricadjust'] = (df_clean['SPEC_type949'].isin(temp_lst)).fillna(False).astype(int)
temp_lst = ['electrically adjustable']
df_clean['SPEC_doormirrorPGside_electricadjust'] = (df_clean['SPEC_type949'].isin(temp_lst)).fillna(False).astype(int)
temp_lst = ['1', '1:0','1: ']
df_clean['SPEC_doormirrorDRside_heater'] = (df_clean['SPEC_heated950'].isin(temp_lst)).fillna(False).astype(int)
temp_lst = ['1', '0:1']
df_clean['SPEC_doormirrorPGside_heater'] = (df_clean['SPEC_heated950'].isin(temp_lst)).fillna(False).astype(int)
df_clean['SPEC_doormirror_color_painted'] = df_clean['SPEC_color951'].str.contains('painted').fillna(False).astype(int)
df_clean['SPEC_doormirror_color_black'] = df_clean['SPEC_color951'].str.contains('black').fillna(False).astype(int)
df_clean['SPEC_doormirror_color_chrome'] = df_clean['SPEC_color951'].str.contains('chrome').fillna(False).astype(int)
df_clean['SPEC_doormirror_color_toned'] = df_clean['SPEC_color951'].str.contains('toned').fillna(False).astype(int)
df_clean['SPEC_doormirror_color_alloy'] = df_clean['SPEC_color951'].str.contains('alloy').fillna(False).astype(int)
df_clean['SPEC_doormirror_autodimming'] = df_clean['SPEC_auto-dimming952'].str.contains('1').fillna(False).astype(int)
temp_lst = ['automatic', 'automatic:not installed']
df_clean['SPEC_doormirrorDRside_tiltforreverse'] = (df_clean['SPEC_tilting for reversing'].isin(temp_lst)).fillna(False).astype(int)
temp_lst = ['automatic', 'not installed:automatic']
df_clean['SPEC_doormirrorPGside_tiltforreverse'] = (df_clean['SPEC_tilting for reversing'].isin(temp_lst)).fillna(False).astype(int)
df_clean['SPEC_doormirror_indicatorlights'] = df_clean['SPEC_indicator lights'].str.contains('1').fillna(False).astype(int)

df_clean['SPEC_electricBlind'] = df_clean['SPEC_type975'].str.contains('electric').fillna(False).astype(int)

df_clean['SPEC_intermittentwiper_variable'] = df_clean['SPEC_intermittent wipe'].str.contains('variable').fillna(False).astype(int)
df_clean['SPEC_intermittentwiper_automatic'] = df_clean['SPEC_intermittent wipe'].str.contains('automatic').fillna(False).astype(int)
df_clean['SPEC_intermittentwiper_fixed'] = df_clean['SPEC_intermittent wipe'].str.contains('automatic').fillna(False).astype(int)

df_clean['SPEC_Powerwindow_RR'] = df_clean['SPEC_location981'].str.contains('rear').fillna(False).astype(int)

df_clean['SPEC_wheelrim_alloy'] = df_clean['SPEC_rim type'].str.contains('alloy').fillna(False).astype(int)
df_clean['SPEC_wheelrim_steel'] = df_clean['SPEC_rim type'].str.contains('steel').fillna(False).astype(int)
df_clean['SPEC_wheelrim_composite'] = df_clean['SPEC_rim type'].str.contains('composite').fillna(False).astype(int)
df_clean['SPEC_wheelrim_chrome'] = df_clean['SPEC_rim type'].str.contains('chrome').fillna(False).astype(int)
df_clean['SPEC_wheelrim_diameter_inch'] = df_clean["SPEC_rim diameter (in)"].apply(lambda x:\
                                            max([float(i) for i in str(x).split(':') if i !=' '])
                                            )
df_clean['SPEC_wheelrim_width_inch'] = df_clean["SPEC_rim width (in)"].apply(lambda x:\
                                            max([float(i) for i in str(x).split(':') if i !=' '])
                                            )

df_clean['SPEC_wheelcover_partial'] = df_clean['SPEC_wheel covers'].str.contains('partial').fillna(False).astype(int)
df_clean['SPEC_wheelcover_full'] = df_clean['SPEC_wheel covers'].str.contains('full').fillna(False).astype(int)
df_clean['SPEC_wheel_twotone'] = df_clean['SPEC_two-tone1056'].str.contains('1').fillna(False).astype(int)

df_clean['SPEC_tire_width_mm'] = df_clean["SPEC_tire width"].apply(lambda x:\
                                            max([float(i) for i in str(x).split(':') if i !=' ']))
df_clean['SPEC_tire_aspect_%'] = df_clean["SPEC_tire profile"].apply(lambda x:\
                                            max([float(i) for i in str(x).split(':') if i !=' ']))
df_clean['SPEC_tire_diameter_inch'] = df_clean["SPEC_diameter"].apply(lambda x:\
                                            max([float(i) for i in str(x).split(':') if i !=' ']))

df_clean['SPEC_runflattire'] = df_clean['SPEC_run flat'].str.contains('1').fillna(False).astype(int)

df_clean['SPEC_Sparetiresize_fullsize'] = df_clean['SPEC_type1063'].str.contains('fullsize').fillna(False).astype(int)
df_clean['SPEC_Sparetiretype_alloy'] = df_clean['SPEC_rim type1064'].str.contains('alloy').fillna(False).astype(int)
# Out:
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:241: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_Basepainttype_black'] = (df_clean['SPEC_type396'] == 'black').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:242: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_Basepainttype_mica'] = (df_clean['SPEC_type396'] == 'mica').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:243: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_Basepainttype_gloss'] = (df_clean['SPEC_type396'] == 'gloss').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:245: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_Sunroof_electric'] = ((df_clean['SPEC_operation702'] == 'electric')|(df_clean['SPEC_operation702'] == 'electric:removable')).fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:246: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_Sunroof_remote'] = (df_clean['SPEC_operation702'] == 'remote').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:248: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_Roofrail_crossbars'] = ((df_clean['SPEC_cross bars'] == 'fixed')|(df_clean['SPEC_cross bars'] == 'removable')).fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:250: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_Convertibleroof_soft'] = (df_clean['SPEC_type706'] == 'soft').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:251: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_Convertibleroof_hard'] = ((df_clean['SPEC_type706'] == 'hard')|(df_clean['SPEC_type706'] == 'hard:soft')).fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:252: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_Convertibleroof_foldable'] = ((df_clean['SPEC_type706'] == 'soft:foldable hard top')|(df_clean['SPEC_type706'] == 'foldable hard top')).fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:253: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_Convertibleroof_glassRRwindow'] = (df_clean['SPEC_glass rear window'] == 'yes').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:254: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_Convertibleroof_electric'] = ((df_clean['SPEC_operation707'] == 'electric')|(df_clean['SPEC_operation707'] == 'electric:remote')).fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:255: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_Convertibleroof_remote'] = (df_clean['SPEC_operation707'] == 'remote').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:257: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_ConvRolloverprotection_concealed'] = (df_clean['SPEC_type709'] == 'concealed system').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:258: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_ConvRolloverprotection_fixedhoop'] = (df_clean['SPEC_type709'] == 'fixed hoop').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:260: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_FRAirbag_switchoff'] = (df_clean['SPEC_occupant switch off'] == ' :yes').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:261: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_FRAirbag_intelligent'] = ((df_clean['SPEC_intelligent'] == '1')|(df_clean['SPEC_intelligent'] == '0:1')).fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:263: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_SideAirbag_FR'] = df_clean['SPEC_location722'].str.contains('front').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:264: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_SideAirbag_RR'] = df_clean['SPEC_location722'].str.contains('rear').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:265: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_SideAirbag_headprotect'] = ((df_clean['SPEC_head protection'] == '1')|(df_clean['SPEC_head protection'] == '1:')).fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:267: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_CurtainAirbag_numRows'] = df_clean['SPEC_location724'].apply(lambda x:
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:276: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_KneeAirbag_driver'] = df_clean['SPEC_location726'].str.contains('driver').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:277: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_KneeAirbag_passenger'] = df_clean['SPEC_location726'].str.contains('passenger').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:279: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_headrestraints_numrows'] = df_clean['SPEC_location728'].apply(lambda x:
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:288: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_headrestraints_heightadjust'] = df_clean['SPEC_height adjustable'].str.contains('1').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:289: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_headrestraints_electricadjust'] = df_clean['SPEC_electric adjustable'].str.contains('yes').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:290: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_headrestraints_active'] = df_clean['SPEC_active'].str.contains('1').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:291: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_headrestraints_num'] = df_clean["SPEC_charging cable included"].apply(lambda x:\
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:294: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_FRseatbelt_DRPG'] = df_clean['SPEC_seat position'].str.contains('driver:passenger').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:295: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_FRseatbelt_Center'] = df_clean['SPEC_seat position'].str.contains('driver:passenger:center').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:296: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_FRseatbelt_pretentioners'] = df_clean['SPEC_pre-tensioners'].str.contains('1').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:297: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_FRseatbelt_heightadjust'] = df_clean['SPEC_height adjustable738'].str.contains('1').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:298: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_FRseatbelt_extenders'] = df_clean['SPEC_extenders'].str.contains('1').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:300: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_RRseatbelt_DRPG'] = df_clean['SPEC_seat position740'].str.contains('driver:passenger').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:301: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_RRseatbelt_DRPGCenter'] = df_clean['SPEC_seat position740'].str.contains('driver:passenger:center').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:302: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_RRseatbelt_center3point'] = df_clean['SPEC_type741'].str.contains(' : :3-point').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:303: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_RRseatbelt_centerreel'] = df_clean['SPEC_operation742'].str.contains(' : :reel').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:304: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_RRseatbelt_pretentioners'] = df_clean["SPEC_pre-tensioners743"].apply(lambda x:\
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:306: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_RRseatbelt_heightadjust'] = df_clean["SPEC_height adjustable744"].apply(lambda x:\
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:309: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_3rdrowseatbelt_DRPG'] = df_clean["SPEC_seat position746"].str.contains('driver:passenger').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:310: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_3rdrowseatbelt_Center'] = df_clean["SPEC_seat position746"].str.contains('driver:passenger:center').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:311: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_3rdrowseatbelt_Center3point'] = df_clean["SPEC_type747"].str.contains(' : :3-point').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:312: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_3rdrowseatbelt_centerreel'] = df_clean['SPEC_operation748'].str.contains(' : :reel').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:314: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_AutomaticEmergencyBrake_lowspeed_front'] = df_clean['SPEC_brakes at low speed'].str.contains('front').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:315: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_AutomaticEmergencyBrake_lowspeed_rear'] = df_clean['SPEC_brakes at low speed'].str.contains('rear').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:317: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_AutonomousDriving_level1'] = (df_clean['SPEC_level'] == '1 - driver assistance').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:318: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_AutonomousDriving_level2'] = (df_clean['SPEC_level'] == '2 - partial automation').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:319: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_AutonomousDriving_level3'] = (df_clean['SPEC_level'] == '3 - conditional automation').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:321: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_NHTSA_sideimpact_5'] = df_clean['SPEC_side impact'].str.contains('5').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_NHTSA_sideimpact_4'] = df_clean['SPEC_side impact'].str.contains('4').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:323: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_NHTSA_sideimpact_3'] = df_clean['SPEC_side impact'].str.contains('3').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:324: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_NHTSA_sideimpact_2'] = df_clean['SPEC_side impact'].str.contains('2').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:325: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_NHTSA_sideimpact_1'] = df_clean['SPEC_side impact'].str.contains('1').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:327: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_NHTSA_rollover_5'] = df_clean['SPEC_rollover rating'].str.contains('5').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:328: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_NHTSA_rollover_4'] = df_clean['SPEC_rollover rating'].str.contains('4').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:329: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_NHTSA_rollover_3'] = df_clean['SPEC_rollover rating'].str.contains('3').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:330: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_NHTSA_rollover_2'] = df_clean['SPEC_rollover rating'].str.contains('2').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:331: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_NHTSA_rollover_1'] = df_clean['SPEC_rollover rating'].str.contains('1').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:333: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_NHTSA_overall_5'] = df_clean['SPEC_overall'].str.contains('5').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:334: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_NHTSA_overall_4'] = df_clean['SPEC_overall'].str.contains('4').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:335: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_NHTSA_overall_3'] = df_clean['SPEC_overall'].str.contains('3').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:336: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_NHTSA_overall_2'] = df_clean['SPEC_overall'].str.contains('2').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:337: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_NHTSA_overall_1'] = df_clean['SPEC_overall'].str.contains('1').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:339: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_NHTSA_frontcrash_5'] = df_clean['SPEC_frontal crash rating'].str.contains('5').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:340: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_NHTSA_frontcrash_4'] = df_clean['SPEC_frontal crash rating'].str.contains('4').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:341: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_NHTSA_frontcrash_3'] = df_clean['SPEC_frontal crash rating'].str.contains('3').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:342: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_NHTSA_frontcrash_2'] = df_clean['SPEC_frontal crash rating'].str.contains('2').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:343: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_NHTSA_frontcrash_1'] = df_clean['SPEC_frontal crash rating'].str.contains('1').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:345: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_IIHS_sideimpact_Good'] = df_clean['SPEC_side impact'].str.contains('Good').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:346: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_IIHS_sideimpact_Acceptable'] = df_clean['SPEC_side impact'].str.contains('Acceptable').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:347: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_IIHS_sideimpact_Marginal'] = df_clean['SPEC_side impact'].str.contains('Marginal').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:348: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_IIHS_sideimpact_Poor'] = df_clean['SPEC_side impact'].str.contains('Poor').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:350: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_IIHS_moderateoverlap_Good'] = df_clean['SPEC_moderate overlap front test'].str.contains('Good').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:351: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_IIHS_moderateoverlap_Acceptable'] = df_clean['SPEC_moderate overlap front test'].str.contains('Acceptable').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:352: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_IIHS_moderateoverlap_Marginal'] = df_clean['SPEC_moderate overlap front test'].str.contains('Marginal').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:353: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_IIHS_moderateoverlap_Poor'] = df_clean['SPEC_moderate overlap front test'].str.contains('Poor').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:355: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_IIHS_smalloverlapFRDR_Good'] = df_clean['SPEC_small overlap front - driver'].str.contains('Good').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:356: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_IIHS_smalloverlapFRDR_Acceptable'] = df_clean['SPEC_small overlap front - driver'].str.contains('Acceptable').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:357: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_IIHS_smalloverlapFRDR_Marginal'] = df_clean['SPEC_small overlap front - driver'].str.contains('Marginal').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:358: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_IIHS_smalloverlapFRDR_Poor'] = df_clean['SPEC_small overlap front - driver'].str.contains('Poor').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:360: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_IIHS_smalloverlapFRPG_Good'] = df_clean['SPEC_small overlap front - passenger'].str.contains('Good').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:361: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_IIHS_smalloverlapFRPG_Acceptable'] = df_clean['SPEC_small overlap front - passenger'].str.contains('Acceptable').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:362: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_IIHS_smalloverlapFRPG_Marginal'] = df_clean['SPEC_small overlap front - passenger'].str.contains('Marginal').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:363: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_IIHS_smalloverlapFRPG_Poor'] = df_clean['SPEC_small overlap front - passenger'].str.contains('Poor').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:365: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_IIHS_roofstrength_Good'] = df_clean['SPEC_roof strength test'].str.contains('Good').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:366: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_IIHS_roofstrength_Acceptable'] = df_clean['SPEC_roof strength test'].str.contains('Acceptable').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:367: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_IIHS_roofstrength_Marginal'] = df_clean['SPEC_roof strength test'].str.contains('Marginal').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:368: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_IIHS_roofstrength_Poor'] = df_clean['SPEC_roof strength test'].str.contains('Poor').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:370: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_IIHS_RRcrashprotectHeadrestraint_Good'] = df_clean['SPEC_rear crash protect/head restraint rating'].str.contains('Good').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:371: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_IIHS_RRcrashprotectHeadrestraint_Acceptable'] = df_clean['SPEC_rear crash protect/head restraint rating'].str.contains('Acceptable').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:372: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_IIHS_RRcrashprotectHeadrestraint_Marginal'] = df_clean['SPEC_rear crash protect/head restraint rating'].str.contains('Marginal').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:373: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_IIHS_RRcrashprotectHeadrestraint_Poor'] = df_clean['SPEC_rear crash protect/head restraint rating'].str.contains('Poor').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:375: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_IIHS_TopSafetyPick'] = ((df_clean['SPEC_top Safety Pick status'] == 'TSP: ')|(df_clean['SPEC_top Safety Pick status'] == 'TSP')).fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:378: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_Seat_num'] = df_clean["SPEC_charging cable included"].apply(lambda x:\
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:382: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_FRseat_captain'] = (df_clean['SPEC_type808'] == "captain's").fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:385: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_FRDRseat_reclining_manual'] = (df_clean['SPEC_reclining type'].isin(temp_lst)).fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:387: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_FRPGseat_reclining_manual'] = (df_clean['SPEC_reclining type'].isin(temp_lst)).fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:389: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_FRDRseat_reclining_electric'] = (df_clean['SPEC_reclining type'].isin(temp_lst)).fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:391: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_FRPGseat_reclining_electric'] = (df_clean['SPEC_reclining type'].isin(temp_lst)).fillna(False).astype(int)
# ...
#   df_clean['SPEC_FRDRseat_tilt_electric'] = (df_clean['SPEC_tilt type'].isin(temp_lst)).fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:448: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_FRPGseat_tilt_electric'] = (df_clean['SPEC_tilt type'].isin(temp_lst)).fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:450: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_FRDRseat_tilt_memory'] = (df_clean['SPEC_tilt type'].isin(temp_lst)).fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:452: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_FRPGseat_tilt_memory'] = (df_clean['SPEC_tilt type'].isin(temp_lst)).fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:455: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_FRDRseat_thighsupport_manual'] = (df_clean['SPEC_thigh support type'].isin(temp_lst)).fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:457: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_FRPGseat_thighsupport_manual'] = (df_clean['SPEC_thigh support type'].isin(temp_lst)).fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:459: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_FRDRseat_thighsupport_electric'] = (df_clean['SPEC_thigh support type'].isin(temp_lst)).fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:461: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_FRPGseat_thighsupport_electric'] = (df_clean['SPEC_thigh support type'].isin(temp_lst)).fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:463: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_FRDRseat_thighsupport_memory'] = (df_clean['SPEC_thigh support type'].isin(temp_lst)).fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:465: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_FRPGseat_thighsupport_memory'] = (df_clean['SPEC_thigh support type'].isin(temp_lst)).fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:468: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_FRDRseat_heated'] = (df_clean['SPEC_heated'].isin(temp_lst)).fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:470: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_FRPGseat_heated'] = (df_clean['SPEC_heated'].isin(temp_lst)).fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:473: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_FRDRseat_massage'] = (df_clean['SPEC_active/massage'].isin(temp_lst)).fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:475: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_FRPGseat_massage'] = (df_clean['SPEC_active/massage'].isin(temp_lst)).fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:478: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_FRDRseat_ventilated'] = (df_clean['SPEC_ventilated'].isin(temp_lst)).fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:480: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_FRPGseat_ventilated'] = (df_clean['SPEC_ventilated'].isin(temp_lst)).fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:483: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_FRDRseat_climatecontroll'] = (df_clean['SPEC_climate controlled'].isin(temp_lst)).fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:485: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_FRPGseat_climatecontroll'] = (df_clean['SPEC_climate controlled'].isin(temp_lst)).fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:488: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_FRPGseat_folding'] = (df_clean['SPEC_folding809'].isin(temp_lst)).fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:491: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_FRPGseat_RRPGcontroll'] = (df_clean['SPEC_rear passenger control'].isin(temp_lst)).fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:494: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_RRseat_reclining_manual'] = (df_clean['SPEC_reclining type814'].isin(temp_lst)).fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:497: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_RRseat_reclining_electric'] = (df_clean['SPEC_reclining type814'].isin(temp_lst)).fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:500: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_RRseat_reach_manual'] = (df_clean['SPEC_reach type815'].isin(temp_lst)).fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:503: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_RRseat_reach_electric'] = (df_clean['SPEC_reach type815'].isin(temp_lst)).fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:506: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_RRseat_folding'] = (df_clean['SPEC_folding820'].isin(temp_lst)).fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:508: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_Steering_alloy'] = df_clean['SPEC_type864'].str.contains('alloy').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:509: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_Steering_plastic'] = df_clean['SPEC_type864'].str.contains('plastic').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:510: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_Steering_leather'] = df_clean['SPEC_type864'].str.contains('^(?!.*synthetic leather).*leather', regex=True).fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:511: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_Steering_syntheticleather'] = df_clean['SPEC_type864'].str.contains('synthetic leather').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:512: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_Steering_wood'] = df_clean['SPEC_type864'].str.contains('wood').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:513: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_Steering_suede'] = df_clean['SPEC_type864'].str.contains('suede').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:515: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_Console_dashboard'] = df_clean['SPEC_location882'].str.contains('dashboard').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:516: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_Console_floor'] = df_clean['SPEC_location882'].str.contains('floor').fillna(False).astype(int)
# /var/folders/57/0jgh1fz973nb1t0tp3f4y3b80000gn/T/ipykernel_27336/2938355413.py:517: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_clean['SPEC_Console_overhead'] = df_clean['SPEC_location882'].str.contains('overhead').fillna(False).astype(int)

# %%
#spec_names = pd.DataFrame(df_clean.filter(like="SPEC_", axis=1).dtypes, columns=['Datatype'])

# %%
# for i, item in enumerate(spec_names[spec_names['Datatype'] == 'object'].index):
#     print(i, '============='+item+'==============')
#     print(df_clean[item].value_counts())
#     print('\n')
# Out:
# 0 =============SPEC_body length==============
# regular     9160
# extended     437
# Name: SPEC_body length, dtype: int64
#
#
# 1 =============SPEC_brand name==============
# none                11145
# Bose                 1095
# Bang & Olufsen        416
# harman/kardon         342
# JBL                   281
# Sony                  181
# ELS                   155
# Burmester             144
# Infinity              102
# Rockford Fosgate       96
# Revel                  59
# Alpine                 57
# Meridian               43
# other                  42
# Pioneer                27
# Fender                 20
# Mark Levinson          12
# Krell                   6
# Dimension               4
# Lexicon                 3
# Beats                   2
# Name: SPEC_brand name, dtype: int64
#
#
# 2 =============SPEC_4D enhancement==============
# no    992
# Name: SPEC_4D enhancement, dtype: int64
#
#
# 3 =============SPEC_type16==============
# element       376
# roof          271
# diversity     145
# fixed mast    103
# Name: SPEC_type16, dtype: int64
#
#
# 4 =============SPEC_brand name18==============
# none                13950
# Sony                   80
# other                  78
# Bang & Olufsen         45
# Rockford Fosgate       32
# Infinity               12
# harman/kardon          12
# Bose                    5
# Naim                    3
# JBL                     2
# Alpine                  1
# Name: SPEC_brand name18, dtype: int64
#
#
# 5 =============SPEC_radio==============
# AM/FM    14265
# FM          18
# Name: SPEC_radio, dtype: int64
#
#
# 6 =============SPEC_type23==============
# steering wheel mounted           10983
# steering wheel mounted & rear      219
# Name: SPEC_type23, dtype: int64
#
#
# 7 =============SPEC_location==============
# glove box         239
# dashboard         169
# centre console     12
# armrest             8
# Name: SPEC_location, dtype: int64
#
#
# 8 =============SPEC_media type==============
# DVD    260
# CD     168
# Name: SPEC_media type, dtype: int64
#
#
# 9 =============SPEC_ipod rear==============
# no    13824
# Name: SPEC_ipod rear, dtype: int64
#
#
# 10 =============SPEC_Body style==============
# standard    14432
# Name: SPEC_Body style, dtype: int64
#
#
# 11 =============SPEC_Body type30==============
# sport utility vehicle    4229
# pickup                   3259
# sedan                    2417
# hatchback                 993
# cargo van                 911
# coupe                     808
# passenger van             358
# cutaway                   343
# convertible               335
# combi                     313
# chassis cab               199
# wagon                      80
# car van                    76
# chassis cowl               50
# targa                      31
# mini MPV                   18
# Minivan                    12
# Name: SPEC_Body type30, dtype: int64
#
#
# 12 =============SPEC_cab type33==============
# none        6121
# crew        1935
# extended     965
# regular      618
# Name: SPEC_cab type33, dtype: int64
#
#
# 13 =============SPEC_cab type manufacturer's name==============
# Crew Cab        1231
# Double Cab       494
# Regular Cab      316
# SuperCrew        193
# CrewMax          166
# Quad Cab         155
# King Cab         112
# Extended Cab     100
# SuperCab          96
# Access Cab        95
# Single Cab        36
# Name: SPEC_cab type manufacturer's name, dtype: int64
#
#
# 14 =============SPEC_local body type==============
# sport utility vehicle    3475
# pickup                   3259
# sedan                    2419
# cargo van                1106
# hatchback                 887
# coupe                     858
# crossover                 808
# passenger van             358
# chassis cab               342
# convertible               301
# cutaway                   200
# combi                     128
# wagon                      95
# Minivan                    52
# chassis cowl               50
# roadster                   34
# targa                      31
# mini MPV                   29
# Name: SPEC_local body type, dtype: int64
#
#
# 15 =============SPEC_roof type34==============
# standard      5375
# high           535
# semi-high      180
# None            86
# extra-high       3
# Name: SPEC_roof type34, dtype: int64
#
#
# 16 =============SPEC_wheelbase type35==============
# short     12060
# long       1978
# medium      394
# Name: SPEC_wheelbase type35, dtype: int64
#
#
# 17 =============SPEC_platform code37==============
# GMT K2XX    646
# MLB         551
# DS          489
# NCV3        445
# V36X        404
#            ...
# s             3
# G83           2
# G26           2
# Model Y       2
# E70           1
# Name: SPEC_platform code37, Length: 133, dtype: int64
#
#
# 18 =============SPEC_color==============
# body color    60
# argent        20
# black/grey     9
# Name: SPEC_color, dtype: int64
#
#
# 19 =============SPEC_location44==============
# roof                4088
# trunk/hatch         1452
# roof:trunk/hatch      27
# Name: SPEC_location44, dtype: int64
#
#
# 20 =============SPEC_electrically deployed==============
# 0      12909
# 0       1446
# 1         69
# 0:         6
#  :0        2
# Name: SPEC_electrically deployed, dtype: int64
#
#
# 21 =============SPEC_location50==============
# rear         3328
# side          660
# rear:side     555
# Name: SPEC_location50, dtype: int64
#
#
# 22 =============SPEC_type51==============
# platform                     1159
#  :platform                    387
# fixed cargo box step          194
#  :tube                         81
# fixed cargo box step:tube      11
# tube                            9
# platform:tube                   1
# platform:                       1
# Name: SPEC_type51, dtype: int64
#
#
# 23 =============SPEC_illuminated==============
# 0      13218
# 0        553
#  :0      531
# 1        107
#  :1       23
# Name: SPEC_illuminated, dtype: int64
#
#
# 24 =============SPEC_retractable==============
# no            3308
# no:            477
# electric:        7
# Name: SPEC_retractable, dtype: int64
#
#
# 25 =============SPEC_power retractable==============
# 0      12553
# 0       1195
#  :0      425
# 1        189
#  :1       43
# 0:1       26
# 0:         1
# Name: SPEC_power retractable, dtype: int64
#
#
# 26 =============SPEC_location53==============
# engine                            1218
# fuel tank:transfer case:engine     322
# fuel tank:engine                   249
# transfer case                      143
# transfer case:engine                86
# fuel tank:transfer case             86
# fuel tank                           61
# Name: SPEC_location53, dtype: int64
#
#
# 27 =============SPEC_towing class==============
# IV     2047
# III     448
# I       205
# II       50
# Name: SPEC_towing class, dtype: int64
#
#
# 28 =============SPEC_location60==============
# front:rear    1073
# rear           170
# front           60
# Name: SPEC_location60, dtype: int64
#
#
# 29 =============SPEC_Disc brakes==============
# standard    14432
# Name: SPEC_Disc brakes, dtype: int64
#
#
# 30 =============SPEC_ABS==============
# standard    14432
# Name: SPEC_ABS, dtype: int64
#
#
# 31 =============SPEC_location81==============
# front:rear    10362
# front           447
# Name: SPEC_location81, dtype: int64
#
#
# 32 =============SPEC_color82==============
# painted           5089
# black             2833
# chrome            1304
# painted:black      381
# painted:chrome     229
# toned              200
# chrome:painted      74
# black:painted       25
# argent:painted      22
# argent              21
# black:chrome        12
# painted:toned        3
# argent:black         3
# toned:painted        3
# toned:chrome         2
# chrome:black         2
# Name: SPEC_color82, dtype: int64
#
#
# 33 =============SPEC_type86==============
# flexible    1236
# rigid        993
# Name: SPEC_type86, dtype: int64
#
#
# 34 =============SPEC_type88==============
# hooks          9619
# net            1456
# luggage bar      22
# Name: SPEC_type88, dtype: int64
#
#
# 35 =============SPEC_type94==============
# straight side    3259
# Name: SPEC_type94, dtype: int64
#
#
# 36 =============SPEC_liner==============
# none         2473
# spray-in      406
# composite     358
# insert         22
# Name: SPEC_liner, dtype: int64
#
#
# 37 =============SPEC_pickup bed cover==============
# none             3245
# tonneau cover      14
# Name: SPEC_pickup bed cover, dtype: int64
#
#
# 38 =============SPEC_tipper type==============
# no    3259
# Name: SPEC_tipper type, dtype: int64
#
#
# 39 =============SPEC_bed extender==============
# no    3259
# Name: SPEC_bed extender, dtype: int64
#
#
# 40 =============SPEC_box length==============
# regular    1906
# short      1055
# long        298
# Name: SPEC_box length, dtype: int64
#
#
# 41 =============SPEC_Bulkhead==============
# not available    9082
# option            663
# Name: SPEC_Bulkhead, dtype: int64
#
#
# 42 =============SPEC_Loading ramps==============
# not available    2958
# option             39
# Name: SPEC_Loading ramps, dtype: int64
#
#
# 43 =============SPEC_national tax 1 name==============
# Plug-In Electric Drive Vehicle Credit    159
# Plug-in Electric Vehicle Credit           17
# Gas Guzzler Tax                            5
# GST (5%)                                   5
# PHEV tax credit                            2
# Name: SPEC_national tax 1 name, dtype: int64
#
#
# 44 =============SPEC_national tax 2 name==============
# Plug-in Electric Vehicle Credit    22
# Name: SPEC_national tax 2 name, dtype: int64
#
#
# 45 =============SPEC_Delivery charges==============
# standard    14432
# Name: SPEC_Delivery charges, dtype: int64
#
#
# 46 =============SPEC_price includes batteries==============
# yes    32
# Name: SPEC_price includes batteries, dtype: int64
#
#
# 47 =============SPEC_operation105==============
# remote control    9072
# electric           236
# mechanical          26
# Name: SPEC_operation105, dtype: int64
#
#
# 48 =============SPEC_rear boot/hatch only==============
# yes    2823
# Name: SPEC_rear boot/hatch only, dtype: int64
#
#
# 49 =============SPEC_location116==============
# front         6486
# front:rear    6364
# rear            42
# Name: SPEC_location116, dtype: int64
#
#
# 50 =============SPEC_location123==============
# front seats               583
# front seats:rear seats      4
# Name: SPEC_location123, dtype: int64
#
#
# 51 =============SPEC_location125==============
# front         91
# front:rear    37
# rear           6
# Name: SPEC_location125, dtype: int64
#
#
# 52 =============SPEC_location127==============
# driver:passenger    11315
# passenger             679
# driver                  2
# Name: SPEC_location127, dtype: int64
#
#
# 53 =============SPEC_illuminated128==============
# 1      9395
# 0      2547
# 0      2425
# 0:1      63
# 0:        2
# Name: SPEC_illuminated128, dtype: int64
#
#
# 54 =============SPEC_stop/go function==============
# -            9782
# stop & go    1234
# stop          836
# Name: SPEC_stop/go function, dtype: int64
#
#
# 55 =============SPEC_location132==============
# rear               8803
# front:rear         1844
# front:rear:side    1462
# rear:side            45
# Name: SPEC_location132, dtype: int64
#
#
# 56 =============SPEC_type133==============
# camera                                    7576
# sensor:sensor & camera                    1648
# sensor & camera                           1405
# sensor & camera:sensor & camera:camera     779
# sensor                                     236
# camera:sensor & camera:camera              209
# sensor:sensor & camera:sensor               77
# sensor:sensor & camera:camera               55
# sensor & camera:sensor                      40
# sensor:camera                               27
# sensor:sensor & camera:                     16
# sensor & camera:sensor & camera:sensor      13
# camera:sensor & camera                      13
# camera:sensor & camera:sensor & camera      12
# sensor:sensor & camera:sensor & camera      10
#  :camera                                     8
# sensor & camera:camera:camera                7
# camera:                                      5
#  :sensor & camera                            4
# sensor & camera:sensor & camera:             4
#  :sensor & camera:camera                     2
#  :camera:                                    1
# sensor & camera:camera                       1
# Name: SPEC_type133, dtype: int64
#
#
# 57 =============SPEC_information type==============
# 3D and voice          3676
# arrows and voice      1101
# satellite view         350
# full map and voice     175
# voice                   76
# arrows                   4
# full map                 1
# Name: SPEC_information type, dtype: int64
#
#
# 58 =============SPEC_controls==============
# touch screen    3
# Name: SPEC_controls, dtype: int64
#
#
# 59 =============SPEC_data feed==============
# internet              2078
# internal memory/HD    1781
# SD Card               1553
# DVD                      1
# Name: SPEC_data feed, dtype: int64
#
#
# 60 =============SPEC_display type==============
# color    5058
# mono      202
# none       55
# Name: SPEC_display type, dtype: int64
#
#
# 61 =============SPEC_removable/portable==============
# no    1247
# Name: SPEC_removable/portable, dtype: int64
#
#
# 62 =============SPEC_type151==============
# OTA updates    1723
# OS version      110
# Name: SPEC_type151, dtype: int64
#
#
# 63 =============SPEC_type156==============
# camera            76
# radar             68
# radar & camera    56
# Name: SPEC_type156, dtype: int64
#
#
# 64 =============SPEC_location162==============
# front                            7127
# front:rear                       2414
# front:rear:boot/cargo            2355
# front:boot/cargo                 2129
# front:rear:3rd row:boot/cargo     139
# boot/cargo                         52
# front:rear:3rd row                 30
# front:3rd row:boot/cargo           19
# front:3rd row                      17
# rear                                5
# Name: SPEC_location162, dtype: int64
#
#
# 65 =============SPEC_number of outlets==============
# 1          5310
# 2          3153
# 2:1        2180
# 2:1:1      1324
# 3           638
# 1.0         600
# 2.0         422
# 2:2:1       214
# 2:1:1:1     139
# 3:1          68
# 3:1:1        54
# 2:           49
#  : :1        14
#  :1          14
# 1:2:1        11
# 1:            5
# 1:1:          2
#  :1:1         1
# Name: SPEC_number of outlets, dtype: int64
#
#
# 66 =============SPEC_location164==============
# front:rear            2068
# front                 1675
# front:rear:3rd row     215
# rear:3rd row            10
# rear                     8
# Name: SPEC_location164, dtype: int64
#
#
# 67 =============SPEC_number==============
# 2        1801
# 2.0       572
# 1.0       240
# 3:2       199
# 3         160
# 4:2       156
# 1         154
#  :2        91
# 1:2        65
# 2:1        52
# 4.0        33
# 4          32
# 1:2:2      28
# 2:2:1      27
# 3:2:1      18
# 4:2:2      14
# 2:          9
# 3:2:2       8
# 2:4         8
# 3:2:4       8
# 2:3:2       3
# 3:4         3
# Name: SPEC_number, dtype: int64
#
#
# 68 =============SPEC_screen location==============
# front                                           1339
# single rear middle                                99
# front:back of front seats                         42
# front:single rear middle                          13
# back of front seats                               12
# front:single rear middle:back of front seats       8
# back of rear seats                                 1
# Name: SPEC_screen location, dtype: int64
#
#
# 69 =============SPEC_television==============
# no      1458
# no:        6
# Name: SPEC_television, dtype: int64
#
#
# 70 =============SPEC_digital television==============
# no      1458
# no:        6
# Name: SPEC_digital television, dtype: int64
#
#
# 71 =============SPEC_dual view screen==============
# no        1307
# no:         55
# no: :        8
# Name: SPEC_dual view screen, dtype: int64
#
#
# 72 =============SPEC_DVD==============
# 0        12950
# 1          732
# 0          714
# 0:1         26
# 1:           5
# 0:           3
# 0:1:1        2
# Name: SPEC_DVD, dtype: int64
#
#
# 73 =============SPEC_blu-ray==============
# 0        13033
# 0         1293
# 1           80
# 0:1         12
# 0:           8
# 1:1:         6
# Name: SPEC_blu-ray, dtype: int64
#
#
# 74 =============SPEC_screen size (in)168==============
# 7.0               376
# 8                 240
# 8.0               208
# 8.3                83
# 7                  75
# 9.0                62
# 10.1               47
# 6.1                38
# 10.2               37
# 6.0                28
# 12.3               24
# 16.9               23
# 10.2               20
# 8.00:9.00          20
# 12.3               18
# 8.8                17
# 10.3               17
# 16.90:12.60        15
# 10.3               10
# 16.2                9
# 8.00                6
# 8.00:9.00:7.00      6
# 6.5                 6
# 8.00:11.00          3
# 15.0                3
# 10.0                3
# 8.00:7.00           2
# 12.30:11.40         2
# 12.6                1
# 12.30:              1
# Name: SPEC_screen size (in)168, dtype: int64
#
#
# 75 =============SPEC_touch screen170==============
# 0        13282
# 1          817
# 0          288
# 1:0         34
# 1:0:0        4
# 1:           2
# 0:1          2
#  :1          2
# 0:           1
# Name: SPEC_touch screen170, dtype: int64
#
#
# 76 =============SPEC_type175==============
# automatic    8169
# manual       1075
# Name: SPEC_type175, dtype: int64
#
#
# 77 =============SPEC_includes display==============
# no    882
# Name: SPEC_includes display, dtype: int64
#
#
# 78 =============SPEC_virtual assistant==============
# Alexa     520
# other     433
# Siri      229
# Google     38
# none        9
# Name: SPEC_virtual assistant, dtype: int64
#
#
# 79 =============SPEC_connection type==============
# Via SIM in vehicle    5247
# Via own phone         2257
# Name: SPEC_connection type, dtype: int64
#
#
# 80 =============SPEC_includes phone connection==============
# yes    13047
# Name: SPEC_includes phone connection, dtype: int64
#
#
# 81 =============SPEC_Biometric recognition==============
# not available    1015
# Name: SPEC_Biometric recognition, dtype: int64
#
#
# 82 =============SPEC_location191==============
# rear          6635
# front:rear     633
# front           12
# Name: SPEC_location191, dtype: int64
#
#
# 83 =============SPEC_type192==============
# guidance display                                                            6746
# full auto park & perpendicular & exit                                        182
# full auto park & exit                                                         74
# full automatic parking                                                        55
# remote park & full auto park/exit/perp                                        37
# full auto park & perpendicular                                                32
# semi-automatic park & perpendicular:semi-auto park, perpendicular & exit      24
# full auto park & perpendicular & exit:full auto park & exit                   22
# semi-auto park, perpendicular & exit                                          20
#  :guidance display                                                            17
# full auto park & perpendicular:full auto park & perpendicular & exit          15
# full auto park & perpendicular:semi-auto park, perpendicular & exit           13
# remote park & full auto park/exit                                             12
# semi-automatic park & exit                                                     7
# semi-automatic park & perpendicular                                            6
# semi-automatic parking                                                         6
# full auto park & perpendicular:full auto park & exit                           3
# full auto park & exit:full auto park & perpendicular                           2
# guidance display:semi-auto park, perpendicular & exit                          1
# guidance display:full automatic parking                                        1
# guidance display:full auto park & exit                                         1
# remote park & full auto park/exit:guidance display                             1
# full auto park & perpendicular & exit:guidance display                         1
# Name: SPEC_type192, dtype: int64
#
#
# 84 =============SPEC_automatic braking whilst parking==============
# 0      12132
# 0       1752
# 1        423
# 0:1       64
#  :1       47
# 1:0       11
#  :0        2
# 0:         1
# Name: SPEC_automatic braking whilst parking, dtype: int64
#
#
# 85 =============SPEC_type198==============
# radar             2734
# radar & camera     448
# camera              70
# Name: SPEC_type198, dtype: int64
#
#
# 86 =============SPEC_360 camera extension==============
# no    67
# Name: SPEC_360 camera extension, dtype: int64
#
#
# 87 =============SPEC_connectivity type==============
# embedded sim card        1773
# smartphone pairing        302
# customer sim required      16
# Name: SPEC_connectivity type, dtype: int64
#
#
# 88 =============SPEC_includes battery status checking==============
# yes    202
# Name: SPEC_includes battery status checking, dtype: int64
#
#
# 89 =============SPEC_Other wireless connection==============
# no    3019
# Name: SPEC_Other wireless connection, dtype: int64
#
#
# 90 =============SPEC_location214==============
# front    10
# Name: SPEC_location214, dtype: int64
#
#
# 91 =============SPEC_External dimensions==============
# standard    14430
# Name: SPEC_External dimensions, dtype: int64
#
#
# 92 =============SPEC_measurement standard231==============
# Manufacturer痴 own    6927
# EPA                  1311
# SAE                  1216
# ISO                    20
# DIN                    15
# VDA                    11
# Name: SPEC_measurement standard231, dtype: int64
#
#
# 93 =============SPEC_location234==============
# driver:passenger:rear driver:rear passenger    10683
# driver:passenger                                3200
# driver:passenger:rear passenger                  499
# Name: SPEC_location234, dtype: int64
#
#
# 94 =============SPEC_type235==============
# front hinged                                         13325
# front hinged:front hinged:rear hinged:rear hinged      435
# front hinged:front hinged:sliding                      391
# front hinged:front hinged:double hinged                108
# front hinged:front hinged:sliding:sliding               83
# front hinged:front hinged: :                            20
# Name: SPEC_type235, dtype: int64
#
#
# 95 =============SPEC_electric==============
#  : :no:no        9924
# no                913
#  : :no            468
# no:no:yes:yes       6
#  : :yes:yes         3
# Name: SPEC_electric, dtype: int64
#
#
# 96 =============SPEC_auxiliary door shut==============
# no               14321
# no:no:yes:yes       29
# no:no: :            20
# no: :no:no           2
# Name: SPEC_auxiliary door shut, dtype: int64
#
#
# 97 =============SPEC_hands-free release==============
#  : :no:no    5769
#  : :no        346
#  : :no:        14
#  : : :no        5
# Name: SPEC_hands-free release, dtype: int64
#
#
# 98 =============SPEC_location237==============
# rear                     3198
# passenger:rear           1070
# driver:passenger:rear     220
# Name: SPEC_location237, dtype: int64
#
#
# 99 =============SPEC_operation238==============
# tailgate                                3139
# sliding:double-hinged                    880
# double-hinged                            201
# sliding:sliding:double-hinged            143
# sliding:sliding:lift gate                 64
# dropping gate & single hinged             48
# single-hinged:single-hinged:tailgate      13
# Name: SPEC_operation238, dtype: int64
#
#
# 100 =============SPEC_color244==============
# body color    7535
# black         3608
# chrome        3015
# 2-tone          54
# Name: SPEC_color244, dtype: int64
#
#
# 101 =============SPEC_flush door handles==============
# none        1004
# manual         6
# electric       3
# Name: SPEC_flush door handles, dtype: int64
#
#
# 102 =============SPEC_type246==============
# lifting gate     5333
# double hinged     491
# split gate        109
# dropping gate      60
# hatch/sedan        24
# single hinged       4
# Name: SPEC_type246, dtype: int64
#
#
# 103 =============SPEC_Fire extinguisher==============
# not available    881
# option            30
# Name: SPEC_Fire extinguisher, dtype: int64
#
#
# 104 =============SPEC_configuration==============
# V             7645
# in-line       6065
# horizontal     520
# Name: SPEC_configuration, dtype: int64
#
#
# 105 =============SPEC_valve gear type==============
# double overhead cam    9251
# overhead valve          926
# overhead cam            638
# Name: SPEC_valve gear type, dtype: int64
#
#
# 106 =============SPEC_engine code==============
# 998         543
# ERB         468
# 99M         324
# VK56VD      278
# LV3         274
#            ...
# CHJA          1
# LUZ           1
# S63B44O0      1
# B57D30O0      1
# M57           1
# Name: SPEC_engine code, Length: 238, dtype: int64
#
#
# 107 =============SPEC_Compressor257==============
# turbo           4920
# supercharger      51
# Name: SPEC_Compressor257, dtype: int64
#
#
# 108 =============SPEC_standard met==============
# ULEV II       3029
# FED           2052
# ULEV          1948
# LEV III       1805
# LEV II        1041
# SULEV          892
# PZEV           622
# ULEV III       159
# California     151
# ZEV            148
# SULEV III       94
# SULEV II        77
# LEV             65
# AT-PZEV         20
# EU6 D            2
# Name: SPEC_standard met, dtype: int64
#
#
# 109 =============SPEC_source==============
# EPA    2361
# Name: SPEC_source, dtype: int64
#
#
# 110 =============SPEC_Auxiliary power take-off==============
# not available    9717
# option             12
# Name: SPEC_Auxiliary power take-off, dtype: int64
#
#
# 111 =============SPEC_Electrical system==============
# standard    8279
# Name: SPEC_Electrical system, dtype: int64
#
#
# 112 =============SPEC_Capacitor==============
# not available    13552
# Name: SPEC_Capacitor, dtype: int64
#
#
# 113 =============SPEC_injection/carburetion==============
# gasoline direct injection                  7492
# multi-point injection                      4981
# gasoline direct injection & multi-point    1084
# diesel common rail                          632
# diesel direct injection                      29
# dual injector                                12
# Name: SPEC_injection/carburetion, dtype: int64
#
#
# 114 =============SPEC_Fuel==============
# standard    14432
# Name: SPEC_Fuel, dtype: int64
#
#
# 115 =============SPEC_Fuel type283==============
# unleaded                  8095
# premium unleaded          3561
# E85                       1775
# diesel                     661
# electric                   333
# compressed natural gas       6
# hydrogen                     1
# Name: SPEC_Fuel type283, dtype: int64
#
#
# 116 =============SPEC_other fuel type==============
# none                12293
# unleaded             1736
# premium unleaded      105
# Name: SPEC_other fuel type, dtype: int64
#
#
# 117 =============SPEC_generic primary fuel type==============
# petrol      11552
# alcohol      1876
# diesel        661
# electric      333
# gas             7
# hydrogen        1
# Name: SPEC_generic primary fuel type, dtype: int64
#
#
# 118 =============SPEC_fuel type285==============
# unleaded            1838
# premium unleaded     107
# Name: SPEC_fuel type285, dtype: int64
#
#
# 119 =============SPEC_type287==============
# main    14238
# Name: SPEC_type287, dtype: int64
#
#
# 120 =============SPEC_hybrid type293==============
# active hybrid    755
# mild hybrid      456
# Name: SPEC_hybrid type293, dtype: int64
#
#
# 121 =============SPEC_electric driven wheels296==============
# 4x4      191
# front    154
# rear     110
# Name: SPEC_electric driven wheels296, dtype: int64
#
#
# 122 =============SPEC_battery type==============
# lithium ion                905
# nickel metal hydride       283
# lithium-ion polymer        155
# nickel manganese cobalt     50
# lithium iron phosphate       7
# nickel manganese             1
# Name: SPEC_battery type, dtype: int64
#
#
# 123 =============SPEC_swapable battery==============
# no    252
# Name: SPEC_swapable battery, dtype: int64
#
#
# 124 =============SPEC_wireless charging==============
# no    1187
# Name: SPEC_wireless charging, dtype: int64
#
#
# 125 =============SPEC_battery cell type==============
# pouch        136
# prismatic     61
# cylinder      14
# Name: SPEC_battery cell type, dtype: int64
#
#
# 126 =============SPEC_battery supplier==============
# LG Energy Solution     73
# other                  34
# Panasonic              33
# Primearth EV Energy    14
# SK Innovation           7
# Name: SPEC_battery supplier, dtype: int64
#
#
# 127 =============SPEC_scenario==============
# mode 4:mode 2:mode 3    177
# mode 2:mode 3           100
# mode 4:mode 2            50
# mode 2                    6
# Name: SPEC_scenario, dtype: int64
#
#
# 128 =============SPEC_measurement standard302==============
# SAE            15
# CHADEMO:SAE     1
# Name: SPEC_measurement standard302, dtype: int64
#
#
# 129 =============SPEC_duration (hours)==============
# 0.60:7.50:7.50      20
#  :2.40              15
# 0.56:23.00:8.20     14
# 0.60:50.00:8.50     13
# 2.00:64.75:10.00    12
#                     ..
# 1.00:3.00            1
# 7.50:16.00:          1
# 7.00:21.00:          1
# 7.00:2.50            1
#  :5.50:              1
# Name: SPEC_duration (hours), Length: 77, dtype: int64
#
#
# 130 =============SPEC_voltage (V)303==============
#  :120:240      107
# 120:240         74
# 240:120         23
# 120:            19
#  :120:          16
# 480:240:230      8
# 220:110          7
# 220:110:         6
# 400:240:240      5
# 220:220:         5
# 240:120:240      5
# 480:120:240      4
# 400:120:240      4
# 480:120:         4
# 230              4
# 240              3
#  :110            3
# 240:240:         3
#  :240:240        3
# 120:220          3
#  :230            2
#  :220            2
#  :240            2
#  :120            2
# 480:240:240      1
# 480:240          1
# Name: SPEC_voltage (V)303, dtype: int64
#
#
# 131 =============SPEC_amps (A)==============
#  :20:      29
# 20:        27
#  :20:20    23
# 12:16      15
#  :12:48    14
#  :20:45    14
# 20:14      12
# 20:29      10
#  :20:28    10
#  :17:46     8
#  :20:30     8
#  :20:32     8
# 20:16       8
#  :10:48     6
#  :15:30     6
#  :20:48     6
#  :15:48     6
#  :20:14     5
# 20:15       5
# 16          4
#  : :30      3
#  :10:80     3
# 20:15:      3
# 20:32       3
# 13:16       3
#  :20:29     3
# 20          2
#  :15        2
#  :15:80     2
#  :20:80     2
#  :30:       1
#  :30        1
# 12:         1
# 40          1
# Name: SPEC_amps (A), dtype: int64
#
#
# 132 =============SPEC_max kW supplied to vehicle==============
#  :3.30               22
# 50.00:2.40:6.60      16
# 2.30:7.70            15
# 135.00:2.40:11.00    12
# 100.00:2.40:7.20     11
# 100.00:7.00:7.20      9
# 250.00:2.40:11.50     9
# 2.40:3.00             8
# 135.00: :11.00        8
# 115.00:2.00:11.30     8
# 150.00: :             8
# 50.00:3.60:11.50      7
# 50.00:3.60:7.70       7
# 100.00:2.40:6.60      7
# 350.00: :10.90        7
# 80.00:2.40:7.20       7
# 350.00:2.40:10.90     7
# 50.00:2.00:6.60       6
# 1.40:3.30             6
# 2.40:7.00             6
# 50.00:1.80:11.52      6
# 115.00: :11.30        6
# 2.40:3.30             6
# 130.00: :7.20         5
# 100.00: :7.20         5
# 2.40:11.50            4
#  :2.40:11.50          4
# 2.40:3.70             4
# 250.00: :11.50        4
# 2.40:4.00             4
# 2.40:7.70             3
#  : :7.20              3
# 2.40:3.80             3
# 170.00: :11.00        3
# 100.00: :3.30         3
# 2.40:                 3
#  :3.70                3
# 2.40:7.20             2
# 240                   2
# 300.00: :11.00        2
# 100.00:2.40:7.00      2
#  :2.40:7.20           2
# 2.30:3.70             2
# 1.44:3.30             2
# 1.10:3.70             2
#  :7.00                2
# 100.00:2.40:3.30      1
# 100.00: :7.00         1
# 170.00: :7.60         1
# 1.40:3.50             1
# Name: SPEC_max kW supplied to vehicle, dtype: int64
#
#
# 133 =============SPEC_quoted kW supplied to vehicle==============
# 100.00:2.00:7.00     25
# 2.00:3.00            20
# 2.00:                19
# 135.00:2.00:11.00    15
# 115.00:2.00:11.00    14
# 2.00:4.00            12
#  : :7.00             12
# 250.00:2.00:11.00     9
# 80.00:2.00:7.00       8
# 80.00: :7.00          8
# 2.00:7.00             8
# 50.00:2.00:7.00       7
# 350.00:2.00:11.00     7
# 350.00:2.00:10.90     7
# 150.00:4.00:12.00     7
# 150.00:4.00:10.00     7
# 1.00:3.00             7
# 120.00: :             6
#  :2.00:11.00          6
#  :2.00:7.00           5
# 135.00: :11.00        5
# 40.00:2.00:7.00       5
# 2.00:12.00            4
# 115.00:2.00:12.00     4
# 2.30:7.70             3
# 170.00:2.00:11.00     3
# 150.00:2.00:12.00     2
# 240                   2
#  :7.00                2
# 150.00: :             2
# 300.00:2.00:11.00     2
# 250.00:2.00:11.50     2
# 250.00:2.00:12.00     2
# 1.00:4.00             2
# 170.00:2.00:7.60      1
# Name: SPEC_quoted kW supplied to vehicle, dtype: int64
#
#
# 134 =============SPEC_state of charge starts at (%)==============
# 0.0        67
# 0          34
# 5:0:0      20
# 10:0:0     19
#  :0:0      17
# 20:0:0     15
# 10:10:0    14
# 15:0:0     14
# 15.0        8
# 0:10:0      7
# 10:0:10     5
# 0: :        4
# 0:10        3
#  :0         2
# 2:          2
#  : :0       2
# Name: SPEC_state of charge starts at (%), dtype: int64
#
#
# 135 =============SPEC_state of charge ends at (%)==============
# 100.0         84
# 80:100:100    84
#  :100:100     17
# 80:80:100     14
# 80: :100      14
# 100            7
# 80: :          4
#  :100          4
# 100:80         3
#  : :100        2
# Name: SPEC_state of charge ends at (%), dtype: int64
#
#
# 136 =============SPEC_distance per hour charge (km)==============
# 321.0:6.0:40.0      13
# 1609.0:32.0:71.0     6
# 228.0: :             5
# 6.4:48.3             4
#  :3.2:20.9           3
# 250.0: :             3
#  :4.8:45.0           3
#  :32.0:71.0          3
# 228.0:4.8:45.0       2
#  : :16.1             2
#  :3.2:48.3           1
# 250.0:4.8:45.0       1
# Name: SPEC_distance per hour charge (km), dtype: int64
#
#
# 137 =============SPEC_distance per hour charge (miles)==============
# 200.0:4.0:25.0      13
# 1000.0:20.0:44.0     9
#  :3.0:28.0           6
# 4.0:30.0             4
#  :2.0:12.0           4
#  :2.0:13.0           3
#  : :10.0             2
#  :2.0:30.0           1
# Name: SPEC_distance per hour charge (miles), dtype: int64
#
#
# 138 =============SPEC_Charging station==============
# not available    4397
# Name: SPEC_Charging station, dtype: int64
#
#
# 139 =============SPEC_motor number==============
# 1        578
# 1.0      547
# 1:2      245
# 1:2:3     35
# Name: SPEC_motor number, dtype: int64
#
#
# 140 =============SPEC_power output motor hp/PS==============
# 118                55
# 71                 54
# 60                 46
# 21.0               43
# 201                41
#                    ..
# 15                  1
#  :107.2             1
# 165.0:67.0:67.0     1
# 88.4                1
# 563.0:              1
# Name: SPEC_power output motor hp/PS, Length: 113, dtype: int64
#
#
# 141 =============SPEC_power output motor kW==============
# 88                58
# 52.9              47
# 123.0:50.0        44
# 15.7              43
# 32.1              38
#                   ..
# 125                1
# 432.5:             1
# 99.9               1
# 34.6:26.5:26.5     1
# 125.3              1
# Name: SPEC_power output motor kW, Length: 116, dtype: int64
#
#
# 142 =============SPEC_max torque motor lb ft==============
# 90.0     107
# 184.0     95
# 125       77
# 120       47
# 151.0     34
#         ...
# 273:       2
# 79.0       1
#  :310      1
# 105        1
# 290.0      1
# Name: SPEC_max torque motor lb ft, Length: 70, dtype: int64
#
#
# 143 =============SPEC_max torque motor Nm==============
# 122.0      107
# 249.0       92
# 169         77
# 163         47
# 205.0       34
#           ...
# 161:310      2
# 393.0        1
# 142          1
# 107.0        1
#  :420        1
# Name: SPEC_max torque motor Nm, Length: 76, dtype: int64
#
#
# 144 =============SPEC_electric motor type==============
# ac perm magnet synchronous                                                            631
# bisg belt integrated starter gen                                                      240
# integrated starter generator                                                           78
# ac perm magnet synchronous:                                                            17
# integrated starter generator:ac perm magnet synchronous:ac perm magnet synchronous     10
# ac perm magnet synchronous:ac asyncrhonous induction motor                              7
# ac asyncrhonous induction motor                                                         6
# dc brushless synchronous motor                                                          5
# ac asyncrhonous induction motor:                                                        5
# ac asyncrhonous induction motor:ac perm magnet synchronous                              2
# Name: SPEC_electric motor type, dtype: int64
#
#
# 145 =============SPEC_Battery subscription==============
# not available    4124
# Name: SPEC_Battery subscription, dtype: int64
#
#
# 146 =============SPEC_type309==============
# Type 1 (J1772):Mode 2 (EVSE):CCS (Combo)                85
# Type 1 (J1772):Mode 2 (EVSE)                            63
# Type 1 (J1772)                                          44
# Type 1 (J1772):CCS (Combo)                              39
# Type 1 (J1772):Mode 2 (EVSE):CHAdeMO (JEVS / Type 4)    17
# Mode 2 (EVSE)                                           14
# Type 1 (J1772):Mode 2 (EVSE):Tesla                       9
# Type 1 (J1772):Tesla                                     3
# Tesla                                                    2
# CHAdeMO (JEVS / Type 4)                                  1
# Name: SPEC_type309, dtype: int64
#
#
# 147 =============SPEC_charging cable included==============
# 0        14249
# 1           58
# 1:1:        50
# 1: :        24
# 1:          21
#  :1:        17
# 0            6
#  :1          4
# 0:0:         3
# Name: SPEC_charging cable included, dtype: int64
#
#
# 148 =============SPEC_charging socket DC 1==============
#  : :yes    67
#  :yes      33
# yes         2
# Name: SPEC_charging socket DC 1, dtype: int64
#
#
# 149 =============SPEC_location of DC 1 socket==============
#  : :front side    34
#  :front           23
#  : :front         17
#  : :rear side     16
#  :rear side       10
# rear side          2
# Name: SPEC_location of DC 1 socket, dtype: int64
#
#
# 150 =============SPEC_charging socket DC 2==============
#  : :no    59
#  :no      33
# no         2
# Name: SPEC_charging socket DC 2, dtype: int64
#
#
# 151 =============SPEC_charging socket AC 1==============
# yes: :       67
# yes:         59
# yes          14
# yes: :yes     9
# Name: SPEC_charging socket AC 1, dtype: int64
#
#
# 152 =============SPEC_location of AC 1 socket==============
# front side: :            40
# front side:              24
# rear side:               22
# front:                   22
# front: :                 20
# rear side: :rear side     9
# rear: :                   7
# rear side                 7
# front                     5
# front side                2
# Name: SPEC_location of AC 1 socket, dtype: int64
#
#
# 153 =============SPEC_charging socket AC 2==============
# no:        69
# no: :      59
# no          9
# no: :no     9
# Name: SPEC_charging socket AC 2, dtype: int64
#
#
# 154 =============SPEC_plug & charge==============
# yes    5
# Name: SPEC_plug & charge, dtype: int64
#
#
# 155 =============SPEC_V2B charging==============
# no    5
# Name: SPEC_V2B charging, dtype: int64
#
#
# 156 =============SPEC_V1G charging==============
# no    5
# Name: SPEC_V1G charging, dtype: int64
#
#
# 157 =============SPEC_type322==============
# analogue & TFT        6988
# analogue & digital    4826
# TFT Screen            1317
# analog                 594
# TFT & digital          344
# full digital           197
# Name: SPEC_type322, dtype: int64
#
#
# 158 =============SPEC_head-up display==============
# 0             13734
# windscreen      469
# 0               118
# 1                98
# panel            13
# Name: SPEC_head-up display, dtype: int64
#
#
# 159 =============SPEC_location324==============
# Instrument panel 1:Dashboard centre 1                       4322
# Dashboard centre 1                                          3145
# Instrument panel 1:Dashboard centre 1:Dashboard centre 2     179
# Dashboard centre 1:Dashboard centre 2                        112
# Instrument panel 1                                            61
# Instrument panel 1:Instrument panel 2:Dashboard centre 1      38
# Instrument panel 1:                                           33
# Instrument panel 2:Dashboard centre 1                         19
# Dashboard centre 1:                                            8
# Instrument panel 1:Dashboard centre 1:                         3
# Dashboard centre 2                                             2
# Name: SPEC_location324, dtype: int64
#
#
# 160 =============SPEC_screen size (in)325==============
# 7              1915
# 8              1684
# 6.5             541
# 4.20:8.00       523
# 5               480
#                ...
# 3.50:8.40         1
# 11.00:11.30       1
# 6                 1
# 8.80:6.50         1
#  :9.00            1
# Name: SPEC_screen size (in)325, Length: 155, dtype: int64
#
#
# 161 =============SPEC_orientation==============
#  :fixed          783
# fixed            202
#  :fixed:fixed     18
# Name: SPEC_orientation, dtype: int64
#
#
# 162 =============SPEC_concealable screen==============
#  :no       783
# no         202
#  :no:no     18
# Name: SPEC_concealable screen, dtype: int64
#
#
# 163 =============SPEC_touch screen328==============
# 1        4653
# 0:1      3379
# 0        3165
# 0        2527
#  :1       402
# 0:1:1     179
#  :0        58
# 1:0        29
# 0:0:1      25
# 0:1:0       8
#  :1:1       5
# 0:          2
# Name: SPEC_touch screen328, dtype: int64
#
#
# 164 =============SPEC_multi-touch screen329==============
# 0        8655
# 0        2393
# 0:1      2075
# 1         626
#  :1       202
# 0:        184
#  :0       134
# 0:1:1      62
# 0:1:0      25
# 0:1:       23
#  :0:1      18
# 0:0:1      14
# 1:0         8
# 0:0:        7
#  : :1       4
# 1:          2
# Name: SPEC_multi-touch screen329, dtype: int64
#
#
# 165 =============SPEC_control wheel==============
# 0        13429
# 0          840
#  :1         51
# 0:1         47
#  :0         41
# 1           13
# 1:0          6
#  :0:0        5
# Name: SPEC_control wheel, dtype: int64
#
#
# 166 =============SPEC_mouse control==============
# 0        13429
# 0          963
#  :0         27
#  :1          6
#  :0:0        5
# 1            2
# Name: SPEC_mouse control, dtype: int64
#
#
# 167 =============SPEC_touch pad control==============
# no         904
# no:yes      56
#  :no        27
# no:         11
#  :no:no      5
# Name: SPEC_touch pad control, dtype: int64
#
#
# 168 =============SPEC_roller control==============
# 0        13429
# 0          546
# 1:0        248
# 1          115
#  :0         46
# 0:1         30
# 1:1:         8
# 1:0:0        5
#  :0:0        5
# Name: SPEC_roller control, dtype: int64
#
#
# 169 =============SPEC_number330==============
# 1.0    1399
# 2.0     422
# 1       278
# 2       170
#  :2      24
#  :1      13
# 3.0      12
# Name: SPEC_number330, dtype: int64
#
#
# 170 =============SPEC_control type==============
# wheel              661
#  :wheel            531
#  :touch pad        287
# wheel:             261
#  :mouse             87
# wheel: :            59
# wheel:touch pad     58
# touch pad           37
#  :wheel:            22
# wheel:mouse         10
# mouse                8
#  :mouse:             3
# touch pad:wheel      1
# Name: SPEC_control type, dtype: int64
#
#
# 171 =============SPEC_rim mounted sensor==============
# no    3
# Name: SPEC_rim mounted sensor, dtype: int64
#
#
# 172 =============SPEC_on shift knob==============
# none                  3501
# alloy & leather       2991
# leather               2445
# alloy look            1709
# chrome                 382
# chrome and leather     359
# alloy                  329
# colour high gloss      101
# wood & leather          70
# suede                   24
# wood & alloy            12
# piano black             11
# wood/woodgrain           4
# crystal/glass            3
# Name: SPEC_on shift knob, dtype: int64
#
#
# 173 =============SPEC_on center floor console==============
# none                      3902
# alloy look                2642
# wood/woodgrain            1794
# alloy                      786
# piano black                593
# colour high gloss          519
# wood & leather             291
# synthetic leather          188
# wood & alloy               169
# leather                    156
# alloy/leather              153
# carbon fiber               150
# carbon fiber look          109
# titanium look              102
# painted body colour         99
# alloy & leather & wood      72
# suede                       33
# chrome                      24
# chrome and leather           4
# Name: SPEC_on center floor console, dtype: int64
#
#
# 174 =============SPEC_on doors==============
# alloy look                        3149
# none                              2835
# wood/woodgrain                    2224
# alloy                              754
# wood & leather                     456
# synthetic leather                  392
# leather                            358
# piano black                        295
# carbon fiber look                  272
# alloy/leather                      266
# colour high gloss                  252
# titanium look                      226
# carbon fiber                       123
# suede                               91
# wood & alloy                        89
# alloy look / synthetic leather      88
# alloy & leather & wood              71
# chrome                              12
# wood & suede                         9
# painted body colour                  8
# chrome and leather                   4
# Name: SPEC_on doors, dtype: int64
#
#
# 175 =============SPEC_on instrument panel==============
# alloy look                        5818
# wood/woodgrain                    2034
# alloy                              958
# none                               630
# piano black                        594
# alloy & leather                    313
# colour high gloss                  261
# titanium look                      203
# wood & leather                     178
# carbon fiber look                  156
# wood & alloy                       154
# synthetic leather                  133
# carbon fiber                       122
# alloy & leather & wood              93
# wood & synthetic leather            62
# leather                             60
# alloy & synthetic leather           50
# carbon & leather                    47
# suede                               22
# chrome and leather                  16
# chrome                              12
# wood & suede                         9
# chrome & synthetic leather           6
# alloy look & synthetic leather       4
# Name: SPEC_on instrument panel, dtype: int64
#
#
# 176 =============SPEC_on handbrake grip==============
# none                   10349
# leather                  725
# alloy or alloy look      252
# Name: SPEC_on handbrake grip, dtype: int64
#
#
# 177 =============SPEC_vehicle cab compartment==============
# carpet            6987
# plastic/rubber    2555
# Name: SPEC_vehicle cab compartment, dtype: int64
#
#
# 178 =============SPEC_load area==============
# carpet            4346
# none              4193
# plastic/rubber     827
# wood               102
# Name: SPEC_load area, dtype: int64
#
#
# 179 =============SPEC_removable cargo mat==============
# none              12498
# textile             541
# plastic/rubber      189
# Name: SPEC_removable cargo mat, dtype: int64
#
#
# 180 =============SPEC_material==============
# carpet            564
# plastic/rubber     20
# Name: SPEC_material, dtype: int64
#
#
# 181 =============SPEC_Heated door panels==============
# not available    925
# Name: SPEC_Heated door panels, dtype: int64
#
#
# 182 =============SPEC_type366==============
# alloy              527
# stainless steel    197
# other              154
# carbon fibre         6
# Name: SPEC_type366, dtype: int64
#
#
# 183 =============SPEC_lens type==============
# projector beam     7979
# complex surface    6065
# conventional        338
# Name: SPEC_lens type, dtype: int64
#
#
# 184 =============SPEC_bulb type (low beam)==============
# halogen     7746
# LED         5353
# Bi-Xenon    1180
# Xenon         97
# Name: SPEC_bulb type (low beam), dtype: int64
#
#
# 185 =============SPEC_bulb type (high beam)==============
# halogen     6715
# LED         4840
# Bi-Xenon     822
# Xenon         48
# laser         42
# Name: SPEC_bulb type (high beam), dtype: int64
#
#
# 186 =============SPEC_location380==============
# side indicator lights:low beam:brake lights:rear lights:day time running lights:high beam                     1940
# front fog lights:side indicator lights:low beam:brake lights:rear lights:day time running lights:high beam    1083
# side indicator lights:brake lights:rear lights:day time running lights                                        1026
# day time running lights                                                                                        656
# low beam:brake lights:rear lights:day time running lights:high beam                                            432
#                                                                                                               ...
# side indicator lights:low beam:high beam                                                                         3
# low beam:brake lights:high beam                                                                                  2
# low beam:brake lights:day time running lights:high beam                                                          2
# side indicator lights:low beam:rear lights:high beam                                                             2
# front fog lights:side indicator lights:low beam:day time running lights                                          2
# Name: SPEC_location380, Length: 65, dtype: int64
#
#
# 187 =============SPEC_OLED==============
#  :no:no:no:no:no      1595
# ...
#
#
# 324 =============SPEC_number of speeds==============
# 6           3075
# variable    2063
# 8           1874
# 6           1423
# 7           1303
# 8           1124
# 10           956
# 9            769
# 5            505
# 10           489
# 9            413
# 7            170
# 1            148
# 1             45
# 5             39
# 4             22
# 4             13
# Name: SPEC_number of speeds, dtype: int64
#
#
# 325 =============SPEC_shift lever location==============
# floor             5887
# steering wheel    3554
# column            2503
# dash              2317
# Name: SPEC_shift lever location, dtype: int64
#
#
# 326 =============SPEC_gearchange control type==============
# lever      350
# rotary      60
# buttons     48
# Name: SPEC_gearchange control type, dtype: int64
#
#
# 327 =============SPEC_transmission code==============
# 44U          765
# 6L80         473
# 446          427
# 845RE        364
# 8L90         335
#             ...
# F40            1
# PC60/QA10      1
# R155F          1
# 6HP26 S        1
# R155           1
# Name: SPEC_transmission code, Length: 172, dtype: int64
#
#
# 328 =============SPEC_transmission description==============
# automatic with manual mode             9332
# automatic                              1384
# continuously variable transmission     1195
# manual                                  899
# continuously trans with manual mode     868
# dual clutch sequential trans (DCT)      754
# Name: SPEC_transmission description, dtype: int64
#
#
# 329 =============SPEC_Drive==============
# standard    14432
# Name: SPEC_Drive, dtype: int64
#
#
# 330 =============SPEC_four wheel drive type==============
# none                             8203
# full and part-time               3045
# full-time                        1750
# part-time                        1230
# full and part-time/disconnect     204
# Name: SPEC_four wheel drive type, dtype: int64
#
#
# 331 =============SPEC_North America 4WD type==============
# none    4087
# AWD     2493
# 4WD     1347
# Name: SPEC_North America 4WD type, dtype: int64
#
#
# 332 =============SPEC_Driven wheels917==============
# 4x4      6104
# rear     4175
# front    3760
# Name: SPEC_Driven wheels917, dtype: int64
#
#
# 333 =============SPEC_selection==============
# no                    9950
# automatic             1905
# manual & automatic    1310
# manual                1239
# Name: SPEC_selection, dtype: int64
#
#
# 334 =============SPEC_location920==============
# rear           378
# center         360
# front:rear      17
# rear:center      3
# Name: SPEC_location920, dtype: int64
#
#
# 335 =============SPEC_location922==============
# rear                 2183
# front                 949
# center                761
# front:rear            373
# rear:center            65
# front:rear:center       3
# front:center            2
# Name: SPEC_location922, dtype: int64
#
#
# 336 =============SPEC_type923==============
# electronic               2380
# mechanical               1517
# electronic:                20
# electronic:mechanical      15
# mechanical:                11
#  :mechanical                4
# Name: SPEC_type923, dtype: int64
#
#
# 337 =============SPEC_controlled by==============
# ABS & engine management    917
# Name: SPEC_controlled by, dtype: int64
#
#
# 338 =============SPEC_location931==============
# rear    354
# Name: SPEC_location931, dtype: int64
#
#
# 339 =============SPEC_digital display==============
# no    3
# Name: SPEC_digital display, dtype: int64
#
#
# 340 =============SPEC_heater type==============
# combustion    6640
# electric       302
# heat pump       57
# Name: SPEC_heater type, dtype: int64
#
#
# 341 =============SPEC_independent burner==============
# no    1008
# Name: SPEC_independent burner, dtype: int64
#
#
# 342 =============SPEC_independent burner with timer==============
# no    1008
# Name: SPEC_independent burner with timer, dtype: int64
#
#
# 343 =============SPEC_location936==============
# passenger seat                            5193
# passenger seat:rear seats                 2165
# rear seats                                 242
# passenger seat:individual rear             125
# passenger seat:rear seats:3rd row           24
# passenger seat:3rd row                      18
# passenger seat:3rd row:individual rear       7
# Name: SPEC_location936, dtype: int64
#
#
# 344 =============SPEC_air conditioning type==============
# auto         9230
# manual       5032
# semi-auto      99
# Name: SPEC_air conditioning type, dtype: int64
#
#
# 345 =============SPEC_climate control number of zones==============
# -    5083
# 2    4831
# 1    1491
# 3    1364
# 2     761
# 3     667
# 4      82
# 4      54
# 1      26
# 5       2
# Name: SPEC_climate control number of zones, dtype: int64
#
#
# 346 =============SPEC_type943==============
# independent burner    477
# Name: SPEC_type943, dtype: int64
#
#
# 347 =============SPEC_Ioniser==============
# not available    3
# Name: SPEC_Ioniser, dtype: int64
#
#
# 348 =============SPEC_location948==============
# driver:passenger    13546
# driver                165
# Name: SPEC_location948, dtype: int64
#
#
# 349 =============SPEC_type949==============
# electrically adjustable                          12219
# externally adjustable                             1248
# internally adjustable                               65
# electrically adjustable:externally adjustable        8
# electrically adjustable:                             6
# Name: SPEC_type949, dtype: int64
#
#
# 350 =============SPEC_heated950==============
# 1      9644
# 0      3856
# 0       888
# 1:0      36
# 0:1       4
# 1:        4
# Name: SPEC_heated950, dtype: int64
#
#
# 351 =============SPEC_color951==============
# painted          7843
# black            3792
# chrome           1061
# toned             651
# alloy             154
# chrome:black       32
# painted:toned       6
# carbon              2
# black:toned         1
# Name: SPEC_color951, dtype: int64
#
#
# 352 =============SPEC_auto-dimming952==============
# 0      9948
# 1      1871
# 1:0    1682
# 0       913
# 0:1      10
#  :0       4
# 0:        3
# 1:        1
# Name: SPEC_auto-dimming952, dtype: int64
#
#
# 353 =============SPEC_tilting for reversing==============
# not installed              11259
# automatic                   1389
# not installed:automatic     1189
# automatic:not installed       43
# not installed:switch           6
# not installed:                 3
# Name: SPEC_tilting for reversing, dtype: int64
#
#
# 354 =============SPEC_indicator lights==============
# 1      7549
# 0      6355
# 0       513
# 1:0      15
# Name: SPEC_indicator lights, dtype: int64
#
#
# 355 =============SPEC_location954==============
# driver:passenger    393
# Name: SPEC_location954, dtype: int64
#
#
# 356 =============SPEC_operation957==============
# electric    117
# Name: SPEC_operation957, dtype: int64
#
#
# 357 =============SPEC_Swing away mirrors==============
# not available    7551
# option             87
# Name: SPEC_Swing away mirrors, dtype: int64
#
#
# 358 =============SPEC_type961==============
# fixed        9957
# electric     1111
# hinge         893
# sliding       701
# removable       2
# Name: SPEC_type961, dtype: int64
#
#
# 359 =============SPEC_wipers==============
# -               7840
# intermittent    5010
# constant         197
# Name: SPEC_wipers, dtype: int64
#
#
# 360 =============SPEC_Rear seat monitoring camera==============
# not available    1007
# Name: SPEC_Rear seat monitoring camera, dtype: int64
#
#
# 361 =============SPEC_Double glazing==============
# not available    916
# Name: SPEC_Double glazing, dtype: int64
#
#
# 362 =============SPEC_location974==============
# side                 417
# rear:side             98
# rear                  77
# rear:3rd row side      7
# side:3rd row side      3
# Name: SPEC_location974, dtype: int64
#
#
# 363 =============SPEC_type975==============
# manual             514
# electric:manual     35
# electric            35
# manual:              1
# Name: SPEC_type975, dtype: int64
#
#
# 364 =============SPEC_intermittent wipe==============
# variable     7225
# automatic    6334
# fixed         791
# none           19
# Name: SPEC_intermittent wipe, dtype: int64
#
#
# 365 =============SPEC_type979==============
# high pressure    136
# Name: SPEC_type979, dtype: int64
#
#
# 366 =============SPEC_location981==============
# front:rear    10306
# front          3109
# Name: SPEC_location981, dtype: int64
#
#
# 367 =============SPEC_number of express==============
# 2         4874
# 2:none    3652
# 1:none    2359
# 2         1339
# 1          790
# 1.0        586
# none        38
# 2:          21
#  :none      10
# Name: SPEC_number of express, dtype: int64
#
#
# 368 =============SPEC_electric telescoping==============
# no    7
# Name: SPEC_electric telescoping, dtype: int64
#
#
# 369 =============SPEC_location985==============
# driver:passenger    7077
# passenger            202
# Name: SPEC_location985, dtype: int64
#
#
# 370 =============SPEC_type986==============
# wind-up         6502
# fixed            663
# hinged            79
# hinged:fixed      17
# sliding            5
# Name: SPEC_type986, dtype: int64
#
#
# 371 =============SPEC_location988==============
# driver:passenger    3821
# Name: SPEC_location988, dtype: int64
#
#
# 372 =============SPEC_type989==============
# fixed      3622
# hinged      183
# fixed:        6
# Name: SPEC_type989, dtype: int64
#
#
# 373 =============SPEC_location991==============
# driver:passenger    446
# Name: SPEC_location991, dtype: int64
#
#
# 374 =============SPEC_type992==============
# wind-up    237
# Name: SPEC_type992, dtype: int64
#
#
# 375 =============SPEC_location1002==============
# rear side:rear    6625
# rear               191
# rear side            8
# Name: SPEC_location1002, dtype: int64
#
#
# 376 =============SPEC_Panoramic windscreen==============
# not available    1091
# Name: SPEC_Panoramic windscreen, dtype: int64
#
#
# 377 =============SPEC_Warranty whole vehicle - Total==============
# standard    14372
# Name: SPEC_Warranty whole vehicle - Total, dtype: int64
#
#
# 378 =============SPEC_Warranty anti-corrosion==============
# standard    14372
# Name: SPEC_Warranty anti-corrosion, dtype: int64
#
#
# 379 =============SPEC_measurement standard1052==============
# Manufacturer痴 own    12221
# SAE                    469
# EU                       4
# Name: SPEC_measurement standard1052, dtype: int64
#
#
# 380 =============SPEC_Wheels==============
# standard    14432
# Name: SPEC_Wheels, dtype: int64
#
#
# 381 =============SPEC_location1054==============
# front:rear    14039
# Name: SPEC_location1054, dtype: int64
#
#
# 382 =============SPEC_rim type==============
# alloy                 10231
# steel                  3689
# alloy chrome            432
# steel chrome             52
# composite                13
# steel:steel chrome       11
# alloy:alloy chrome        4
# Name: SPEC_rim type, dtype: int64
#
#
# 383 =============SPEC_rim diameter (in)==============
# 16         2413
# 18         2210
# 17         2028
# 18         1883
# 20         1211
# 17         1038
# 16          817
# 19          723
# 20          658
# 19          593
# 15          219
# 15          193
# 22          143
# 22           98
# 20:21        56
# 19:20        47
# 21           36
# 21           28
# 14           16
# 18:19         6
# 21:20         4
# 19:18         2
# 19:17         2
# 21:22         1
# 17.5:17       1
# 22:18         1
# 17:18         1
# 19:           1
# 21:21.5       1
# 20.5:20       1
# 20:20.5       1
# Name: SPEC_rim diameter (in), dtype: int64
#
#
# 384 =============SPEC_rim width (in)==============
# 7.5          1671
# 8.0          1660
# 6.5          1379
# 8.0          1285
# 7.0          1173
# 7.0          1044
# 7.5           997
# 6.5           670
# 8.5           645
# 9.0           394
# 8.5           354
# 5.5           314
# 6.0           274
# 9.0           249
# 6.0           161
# 8.5:11.5       94
# 9.0:10.0       86
# 8.0:9.0        75
# 7.5:8.5        69
# 8.5:9.5        63
# 9.5:10.5       61
# 8.0:8.5        60
# 9.5            51
# 8.5:11.0       46
# 9.0:11.5       33
# 5.5            32
# 9.5:10.0       29
# 9.0:10.5       23
# 5.0            22
# 9.0:12.0       22
# 5.0            22
# 9.0:9.5        21
# 6.5:8.5        16
# 8.5:9.0        15
# 10.0:10.5      14
# 8.0:7.5        10
# 10.0:11.0       7
# 8.0:11.0        6
# 8.0:10.5        6
# 10.0            6
# 10.5:11.0       5
# 8.0:9.5         5
# 10.5:11.5       5
# 11.0:11.5       5
# 9.5:11.5        5
# 7.5:            4
# 10.0:11.5       4
# 5.5:5.3         4
# 10.5            3
# 9.5:12.5        3
# 9.5:12.0        3
# 8.0:            2
# 6.5:            2
# 7.5:7.0         2
# 9.5             1
# 9.0:12.5        1
# 7.0:            1
# Name: SPEC_rim width (in), dtype: int64
#
#
# 385 =============SPEC_wheel covers==============
# no         11399
# partial     1889
# full         905
# no:           39
#  :no           9
# Name: SPEC_wheel covers, dtype: int64
#
#
# 386 =============SPEC_two-tone1056==============
# 0      11039
# 1       2777
# 0        572
# 0:1       18
# 0:        14
# 1:0       11
#  :0        1
# Name: SPEC_two-tone1056, dtype: int64
#
#
# 387 =============SPEC_structure wheel==============
# no    3029
# Name: SPEC_structure wheel, dtype: int64
#
#
# 388 =============SPEC_Tires==============
# standard    14432
# Name: SPEC_Tires, dtype: int64
#
#
# 389 =============SPEC_location1058==============
# front:rear    14039
# Name: SPEC_location1058, dtype: int64
#
#
# 390 =============SPEC_tire width==============
# 245        1343
# 235        1242
# 235        1213
# 245        1086
# 275        1012
# 225         978
# 265         949
# 225         865
# 255         862
# 215         732
# 215         554
# 265         458
# 205         428
# 255         405
# 195         300
# 275         300
# 205         199
# 195         181
# 285         139
# 185         133
# 225:245     103
# 245:305     100
# 245:275      88
# 255:285      76
# 185          65
# 285          62
# 255:275      62
# 225:255      54
# 235:295      42
# 175          41
# 245:265      39
# 235:255      38
# 235:265      37
# 245:295      35
# 275:285      28
# 265:295      23
# 175          16
# 255:315      14
# 245:285      14
# 315          11
# 275:315      10
# 305:315       9
# 285:325       7
# 295           6
# 235:285       6
# 235:305       6
# 295:305       5
# 235:225       5
# 295:315       5
# 265:325       4
# 325           3
# 255:265       2
# 260           1
# 265:285       1
# 205:225       1
# 235:275       1
# Name: SPEC_tire width, dtype: int64
#
#
# 391 =============SPEC_tire profile==============
# 65       1844
# 55       1353
# 70       1330
# 60       1173
# 45       1150
# 75        980
# 55        931
# 65        778
# 50        748
# 60        707
# 40        640
# 75        440
# 50        438
# 45        324
# 70        287
# 40:35     269
# 40        214
# 85        212
# 35:30     211
# 45:40     162
# 35        102
# 50:45      31
# 35         17
# 55:50      13
# 30         11
# 55:60       8
# 30          7
# 50:60       6
# 50:55       4
# 65:60       4
# 55:45       3
# 45:35       1
# 55:40       1
# Name: SPEC_tire profile, dtype: int64
#
#
# 392 =============SPEC_tire speed rating==============
# H      3449
# S      2751
# V      1903
# T      1226
# R      1086
# Y       741
# W       434
# -       277
# Y:        5
# V:H       3
# W:Y       3
#  :H       2
# Y:W       1
#  :T       1
#  :W       1
# Name: SPEC_tire speed rating, dtype: int64
#
#
# 393 =============SPEC_type1059==============
# all seasons     12297
# conventional      896
# all terrain       702
# mud & snow        109
# other              13
# Name: SPEC_type1059, dtype: int64
#
#
# 394 =============SPEC_run flat==============
# 0      13182
# 1       1172
# 0         76
# 1:0        2
# Name: SPEC_run flat, dtype: int64
#
#
# 395 =============SPEC_official brochure tire size==============
# 1      11259
# 0       2981
# 0        166
# 0:1       14
#  :1        9
# 1:         3
# Name: SPEC_official brochure tire size, dtype: int64
#
#
# 396 =============SPEC_diameter==============
# 16         2357
# 18         2075
# 18         2016
# 17         1934
# 17         1127
# 20         1108
# 16          874
# 19          774
# 20          761
# 19          542
# 15          264
# 15          148
# 22          145
# 22           96
# 20:21        56
# 19:20        47
# 21           36
# 21           28
# 14           16
# 18:19         6
# 17:16         6
# 21:20         4
# 19:17         2
# 19:18         2
# 20:20.5       1
# 21:22         1
# 17.5:17       1
# 22:18         1
# 17:18         1
# 19:           1
# 21:21.5       1
# 20.5:20       1
# Name: SPEC_diameter, dtype: int64
#
#
# 397 =============SPEC_type1063==============
# spacesaver    6565
# fullsize      4456
# inflatable      68
# Name: SPEC_type1063, dtype: int64
#
#
# 398 =============SPEC_rim type1064==============
# steel    10625
# alloy      368
# Name: SPEC_rim type1064, dtype: int64
#
#
# 399 =============SPEC_Rear axle==============
# standard    9753
# Name: SPEC_Rear axle, dtype: int64

# %% [markdown]
# # Impute

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.ensemble import RandomForestRegressor
from pyampute.exploration.mcar_statistical_tests import MCARTest

# %%
backup = df_clean.copy()

# %%
# Fill with 0 because item is not available in the specific segment/models
df_clean['SPEC_total number of USB connections rear'] = df_clean['SPEC_total number of USB connections rear'].fillna(0)
df_clean['SPEC_total number of USB connections front'] = df_clean['SPEC_total number of USB connections front'].fillna(0)
df_clean['SPEC_loading floor height (mm)'] = df_clean['SPEC_loading floor height (mm)'].fillna(0)
df_clean['SPEC_width (mm)'] = df_clean['SPEC_width (mm)'].fillna(0)
df_clean['SPEC_length (mm)'] = df_clean['SPEC_length (mm)'].fillna(0)
df_clean['SPEC_height (mm)'] = df_clean['SPEC_height (mm)'].fillna(0)
df_clean['SPEC_width between wheelhouses (mm)'] = df_clean['SPEC_width between wheelhouses (mm)'].fillna(0)
df_clean['SPEC_screen size (in)'] = df_clean['SPEC_screen size (in)'].fillna(0)
df_clean['SPEC_assisthandles_number'] = df_clean.apply(lambda x: x['SPEC_number of111'] \
                                                        if (x['SPEC_Passenger assist handles'] == 1)\
                                                        else 0 if(x['SPEC_Passenger assist handles'] == 0)\
                                                        else 0, axis=1)
df_clean['SPEC_payload allowance (kg)'] = df_clean['SPEC_payload allowance (kg)'].fillna(0)


# Fill out NA using Domain knowledge
df_clean['SPEC_Airbags_number'] = df_clean.apply(lambda x: x['SPEC_number of795'] \
                                                        if (x['SPEC_Airbags'] == 1)\
                                                        else 0 if(x['SPEC_Airbags'] == 0)\
                                                        else 0, axis=1)
df_clean['SPEC_Airbags_number'] = df_clean.groupby(['Segment_Name'])['SPEC_Airbags_number'].transform(lambda x: x.fillna(x.mode().iloc[0]))
df_clean['SPEC_assisthandles_number'] = df_clean.groupby(['Segment_Name'])['SPEC_assisthandles_number'].transform(lambda x: x.fillna(x.mode().iloc[0]))
df_clean['SPEC_Seating capacity'] = df_clean.groupby(['Segment_Name'])['SPEC_Seating capacity'].transform(lambda x: x.fillna(x.mode().iloc[0]))
df_clean['SPEC_VentilatedDiskBrake_num'] = df_clean.groupby(['Segment_Name'])['SPEC_number of ventilated discs'].transform(lambda x: x.fillna(x.mode().iloc[0]))
df_clean['SPEC_DiskBrake_num'] = df_clean.groupby(['Segment_Name'])['SPEC_number of69'].transform(lambda x: x.fillna(x.mode().iloc[0]))

df_clean['SPEC_rpm for maximum torque (low)'] = df_clean.apply(lambda x: 0 if x['SPEC_Enginetype_BEV']==1 else x['SPEC_rpm for maximum torque (low)'], axis=1)
df_clean['SPEC_rpm for maximum power (low)'] = df_clean.apply(lambda x: 0 if x['SPEC_Enginetype_BEV']==1 else x['SPEC_rpm for maximum power (low)'], axis=1)
df_clean['SPEC_stroke'] = df_clean.apply(lambda x: 0 if x['SPEC_Enginetype_BEV']==1 else x['SPEC_stroke'], axis=1)
df_clean['SPEC_bore'] = df_clean.apply(lambda x: 0 if x['SPEC_Enginetype_BEV']==1 else x['SPEC_bore'], axis=1)
df_clean['SPEC_compression ratio'] = df_clean.apply(lambda x: 0 if x['SPEC_Enginetype_BEV']==1 else x['SPEC_compression ratio'], axis=1)
df_clean['SPEC_cc'] = df_clean.apply(lambda x: x['SPEC_cc'] \
                                                        if (x['SPEC_Enginetype_BEV'] == 0)\
                                                        else 0, axis=1)
df_clean['SPEC_capacity (l)289'] = df_clean.apply(lambda x: 0 if x['SPEC_Enginetype_BEV']==1 else x['SPEC_capacity (l)289'], axis=1)
df_clean['SPEC_number of valves per cylinder']= df_clean.apply(lambda x: 0 if x['SPEC_Enginetype_BEV']==1 else x['SPEC_number of valves per cylinder'], axis=1)
df_clean['SPEC_Liters'] = df_clean.apply(lambda x: 0 if x['SPEC_Enginetype_BEV']==1 else x['SPEC_Liters'], axis=1)
df_clean['SPEC_number of cylinders'] = df_clean.apply(lambda x: 0 if x['SPEC_Enginetype_BEV']==1 else x['SPEC_number of cylinders'], axis=1)

# Edmunds: Take average of the same generation, same model, then impute using knn in the
edmunds_lst = list(df_clean.filter(like='Edmunds').columns)
for item in edmunds_lst:
    df_clean[item] = df_clean.groupby(['PROFILE_Make', 'PROFILE_Model', 'PROFILE_Model generation'])[item].transform(lambda x: x.fillna(x.mean()))
for item in edmunds_lst:
    df_clean[item] = df_clean.groupby(['PROFILE_Make', 'PROFILE_Model'])[item].transform(lambda x: x.fillna(x.mean()))
for item in edmunds_lst:
    df_clean[item] = df_clean.groupby(['PROFILE_Make'])[item].transform(lambda x: x.fillna(x.mean()))
# for item in edmunds_lst:
#     df[item] = df.groupby(['Segment_Name'])[item].transform(lambda x: x.fillna(x.mean()))

# RV: Get average of the same version, same generation, same model, same make, and segment.

rv_lst = list(df_clean.filter(like='RV_').columns)
for item in rv_lst:
    df_clean[item] = df_clean.groupby(['PROFILE_Make', 'PROFILE_Model', 'PROFILE_Model generation', 'PROFILE_Version name'])[item].transform(lambda x: x.fillna(x.mean()))
for item in rv_lst:
    df_clean[item] = df_clean.groupby(['PROFILE_Make', 'PROFILE_Model', 'PROFILE_Model generation'])[item].transform(lambda x: x.fillna(x.mean()))
for item in rv_lst:
    df_clean[item] = df_clean.groupby(['PROFILE_Make', 'PROFILE_Model'])[item].transform(lambda x: x.fillna(x.mean()))
# for item in rv_lst:
#     df[item] = df.groupby(['Segment_Name'])[item].transform(lambda x: x.fillna(x.mean()))


# NCBS: Get average of same generation, same model, same make, and segment.
ncbs_lst = list(df_clean.filter(like='NCBS').columns)
for item in ncbs_lst:
    df_clean[item] = df_clean.groupby(['PROFILE_Make', 'PROFILE_Model', 'PROFILE_Model generation'])[item].transform(lambda x: x.fillna(x.mean()))
for item in ncbs_lst:
    df_clean[item] = df_clean.groupby(['PROFILE_Make', 'PROFILE_Model'])[item].transform(lambda x: x.fillna(x.mean()))
# for item in ncbs_lst:
#     df[item] = df.groupby(['Segment_Name'])[item].transform(lambda x: x.fillna(x.mean()))

# %%
df_clean = df_clean.drop(object_index, axis=1)

# %%
drop_list = ['SPEC_Bumpers', 'SPEC_Mud flaps', 'SPEC_Step','SPEC_location164','SPEC_Parking assistance', 'SPEC_Rear door', 'SPEC_Compressor255',
'SPEC_Luxury trim','SPEC_Headlights', 'SPEC_Front seat belts', 'SPEC_Third row seat belts',
'SPEC_Console', 'SPEC_Cup holders', 'SPEC_Below seat storage','SPEC_Suspension902',
'SPEC_Suspension levelling', 'SPEC_Responsive suspension','SPEC_descent control system', 'SPEC_Engine',
'SPEC_Passenger assist handles', 'SPEC_number of111', 'SPEC_Airbags', 'PROFILE_cab type', 'PROFILE_Make continent group', 
'SPEC_distance (km)1032', 'SPEC_duration (months)1031', 'SPEC_duration (months)1034', 'SPEC_distance (km)1035', 
'SPEC_number of795', 'SPEC_Axle ratio :1','SPEC_number of69','SPEC_number of ventilated discs',
'PROFILE_Country of assembly', 

# Majority is NA
'SPEC_urban (km/l)425', 'SPEC_combined (km/l)427', 'SPEC_country/highway (km/l)426', 'SPEC_total power (kW)', 
'SPEC_number of outlets317', 'SPEC_urban (kWh/km)', 'SPEC_urban (kWh/100 miles)', 'SPEC_urban (km/kWh)', 
'SPEC_country/highway (km/kWh)', 'SPEC_urban (miles/kWh)', 'SPEC_country/highway (miles/kWh)', 'SPEC_urban (Wh/km)', 
'SPEC_country/highway (Wh/km)', 'SPEC_country/highway (kWh/100 miles)', 'SPEC_urban (kWh/mile)', 'SPEC_urban (Wh/mile)', 
'SPEC_country/highway (Wh/mile)', 'SPEC_country/highway (kWh/km)', 'SPEC_country/highway (kWh/mile)', 'SPEC_frunk capacity (l)', 
'SPEC_country/highway (kWh/100km)', 'SPEC_urban (kWh/100km)', 'SPEC_number of zones', 'SPEC_screen size (cm)169', 
'SPEC_national tax 2 amount', 'SPEC_combined (kWh/km)', 'SPEC_combined (kWh/mile)', 'SPEC_combined (Wh/mile)', 
'SPEC_combined (Wh/km)', 'SPEC_gas guzzler tax amount', 'SPEC_combined (miles/kWh)', 'SPEC_seating capacity850', 
'SPEC_combined (km/kWh)', 'SPEC_number of months subscription included203', 'SPEC_useable battery kilowatt hour  (kWh)', 
'SPEC_combined (kWh/100km)', 'SPEC_combined (kWh/100 miles)', 'SPEC_number of months subscription included148', 
'SPEC_max speed on electric power only (km/h)', 'SPEC_break over angle', 'SPEC_distance (km)861', 'SPEC_national tax 1 amount', 
'SPEC_system power (W)',  'SPEC_acceleration 0-100 km/h', 'SPEC_seating capacity847', 
'SPEC_combined (l/100km)430', 'SPEC_distance (km)1041', 'SPEC_duration (months)1040',
'SPEC_duration (months)1028', 'SPEC_distance (km)1029', 'SPEC_duration (months)1037', 'SPEC_distance (km)1038', 'SPEC_capacity', 
'SPEC_battery amp-hour (Ah)', 'SPEC_number of kWh included', 'SPEC_minimum speed to activate (kph)', 
'SPEC_number of months subscription included206', 'SPEC_duration (months)1043', 'SPEC_distance (km)1044', 
'SPEC_battery module count', 'SPEC_overall width folded mirror (mm)', 'SPEC_maximum torque Nm electric motor', 
'SPEC_maximum torque lb/ft electric motor', 'SPEC_maximum power kW electric motor', 'SPEC_maximum power hp/ps electric motor', 
'SPEC_traffic info months of subscription', 'SPEC_distance (km)1026', 'SPEC_duration (months)1025', 'SPEC_battery voltage (V)', 
'SPEC_storage capacity (GB)', 'SPEC_rpm for maximum torque (low)408', 'SPEC_rpm for maximum power (low)406', 
'SPEC_maximum torque lb ft404',  'SPEC_USA - secondary fuel annual tons of CO2', 
'SPEC_maximum speed kph for operation', 'SPEC_secondary fuel CO2 level - g/mile cmbnd', 'SPEC_maximum torque nm405', 
'SPEC_maximum power hp/PS403', 'SPEC_maximum power kw402', 'SPEC_cargo volume (l)', 'SPEC_urban (km/l)', 
'SPEC_country/highway (km/l)', 'SPEC_urban (l/100km)', 'SPEC_country/highway (l/100km)', 'SPEC_maximum speed mph for operation', 
'SPEC_combined (km/l)', 'SPEC_included GB per month', 'SPEC_combined vehicle range (km)', 'SPEC_combined (l/100km)', 'SPEC_range (km)', 'SPEC_range (miles)',
# 13072 missing values
'SPEC_number of cylinders271', 'SPEC_10th gear ratio :1', 'SPEC_number of months subscription included201', 
'SPEC_seating capacity838', 'SPEC_acceleration 0-60 mph', 
'SPEC_maximum speed (km/h)', 'SPEC_number of months subscription included144', 'SPEC_concierge number of months inc',
'SPEC_Other months subscription included', 'SPEC_9th gear ratio :1', 'SPEC_Mirrorlink months subscription included', 
'SPEC_Apple number of months subscription inc', 'SPEC_Android number of months subscription', 'SPEC_number of258', 
'SPEC_satellite radio months of subscription', 'SPEC_period (mths)858', 
'SPEC_8th gear ratio :1', 'SPEC_distance (km)1020', 
'SPEC_duration (months)1019', 'SPEC_distance (km)857', 'SPEC_7th gear ratio :1', 'SPEC_annual subscription', 'SPEC_number of months subscription included181', 
# 7066 missing values
'SPEC_period (mths)', 'SPEC_voltage (V)', 'SPEC_distance (km)855',  'SPEC_axle location',
'SPEC_fuel type octane no.', 'SPEC_6th gear ratio :1', 'SPEC_5th gear ratio :1',  'SPEC_3rd gear ratio :1', 'SPEC_2nd gear ratio :1', 
'SPEC_4th gear ratio :1', 'SPEC_seating capacity822', 'SPEC_USA - annual tons of CO2', 'SPEC_CO2 level - g/mile combined', 'PROFILE_facelift generation',
'SPEC_reverse gear ratio :1', 'SPEC_1st gear ratio :1', 'NCBS_Sample', 'TARGET_Normalized_Volume', 
'TARGET_Normalized_MSRP_x_Normalized_Volume', 'TARGET_MSRP_x_Normalized_Volume', 'SPEC_Seating capacity799',


# Potential Features can be used for analysis
'SPEC_minimum speed to activate (mph)', 'SPEC_departure angle', 'SPEC_approach angle', 'SPEC_gross trailer weight unbraked (kg)', 
'SPEC_compression ratio (high)', 'SPEC_rear seat down (l)','SPEC_max poss gross trailer weight braked kg',
'SPEC_ground clearance unladen (mm)', 'SPEC_gross vehicle weight (kg)','SPEC_all seats in place (l)', 'SPEC_hip room rear (mm)',
'SPEC_shoulder room rear (mm)','SPEC_curb to curb turning circle (mm)', 'SPEC_max possible gross vehicle weight (kg)', 
'SPEC_headroom 3rd row (mm)', 'SPEC_third row seat removed (l)',
'SPEC_shoulder room 3rd row (mm)', 'SPEC_leg room 3rd row (mm)','SPEC_hip room 3rd row (mm)', 'SPEC_overall width inc mirror (mm)',
'SPEC_country/highway (l/100km)423', 'SPEC_urban (l/100km)422', 'SPEC_combined (l/100km)424', 
'SPEC_combined vehicle range (km)428','SPEC_leg room rear (mm)', 'SPEC_headroom rear (mm)','SPEC_hip room front (mm)',
'SPEC_interior volume (l)', 'SPEC_gross trailer weight braked (kg)', 'SPEC_number of electrical adjustments818',  
'SPEC_rear track (mm)', 'SPEC_front track (mm)','SPEC_distance (km)1023', 'SPEC_duration (months)1022',



'TARGET_Base price', 
'SPEC_Liters253', 
'PROFILE_trim classification', 
'TARGET_MSRP_x_Normalized_Volume_byModel', 'TARGET_Normalized_MSRP_x_Normalized_Volume_byModel', 
'TARGET_Normalized_WeightedRetailPrice_byModel', 
'TARGET_Normalized_VolumebyModel', 'TARGET_Normalized_WeightedRetailPrice', 'PROFILE_Model generation', 'SPEC_number of', 
'TARGET_Weighted_RV_byModelBodytype', 'TARGET_Weighted_RetailPrice_byModel', 'SPEC_tire_aspect_%', 
'SPEC_tire_width_mm', 'SPEC_wheelbase (mm)', 'SPEC_Maximum power kW', 'SPEC_Maximum power hp/PS', 'SPEC_Maximum power hp/PS400', 
'SPEC_Maximum power kW399',  'SPEC_smartkey_auto', 'SPEC_onboard charger (kW)', 'SPEC_range (km)298','SPEC_range (miles)299', 'SPEC_maximum battery kilowatt hour (kWh)'
]

# %%
df_clean = df_clean[[col for col in df_clean.columns if col not in drop_list]]

# %%
df_clean = df_clean[~df_clean['TARGET_Volume'].isna()]

# %%
df_clean = df_clean[~df_clean['MACRO_CCI'].isna()]

# %%
null_var = list(null_values[null_values['null_number']>0].index)

# %%
pd.DataFrame(df_clean.isna().sum(), columns=['null_number']).sort_values(by='null_number', ascending=False)
# Out:
#                                                null_number
# SPEC_wheelrim_width_inch                              1190
# SPEC_rpm for maximum torque (low)                      930
# SPEC_rpm for maximum power (low)                       845
# OAO_Score                                              699
# Inventory                                              671
# ...                                                    ...
# SPEC_operates below 50 kph/30 mph                        0
# SPEC_pedestrian collision mitigation steering            0
# SPEC_emergency driver intervention system                0
# SPEC_emergency driver intervention inc park              0
# SPEC_DiskBrake_num                                       0
#
# [1125 rows x 1 columns]

# %% [markdown]
# # Impute: To be revised

# %%
mt = MCARTest(method="little")

# %%
mcar_test = mt.mcar_t_tests(df_clean)

# %%
null_values = pd.DataFrame(df_clean.isna().sum(), columns=['null_number']).sort_values(by='null_number', ascending=False)

# %%
df_clean.columns = [col.replace('(', '').replace(')', '').\
                    replace(' ','_').replace('-','_').replace('/','_').\
                    replace('&','_').replace('.','_').replace("'", '') for col in df_clean.columns]

# %% [markdown]
# ### Conduct further imputing using RandomForest.

# %%
drop_lst = ['PROFILE_Name', 'PROFILE_Unique_Identity', 'PROFILE_Data_date',
       'PROFILE_Version_state', 'PROFILE_Data_status', 
       'PROFILE_Model', 'PROFILE_Version_name',
       'PROFILE_Trim_level', 'PROFILE_Number_of_doors', 
       'PROFILE_Vehicle_type', 'PROFILE_JATO_global_segment',
       'PROFILE_JATO_regional_segment', 'PROFILE_Model_year','PROFILE_Make','PROFILE_Body_type',
        'TARGET_Retail_price_including_delivery_charge',
        'TARGET_Retail_price',  'Segment_Competing_Nissan_Model', 
           'SPEC_Compressor_supercharger','Segment_Name'
           ]

# %%
df_imputer = df_clean.drop(drop_lst, axis=1)

# %%
df_ml = pd.read_csv('/Users/daisukeyagyu/Desktop/UChicago/Courses/Capstone/00_Implementation/Delete_AfterProject/01_Outputs/df_model_1st.csv').dropna()

# %%
item_lst = list(df_ml.columns)+['TARGET_Weighted_RetailPrice']

# %%
df_imputer = df_imputer[[col for col in df_imputer.columns if col not in item_lst]]

# %%
df_imputer = IterativeImputer(RandomForestRegressor(), verbose=2).fit_transform(df_imputer)
# Out:
# [IterativeImputer] Completing matrix with shape (13351, 1105)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[449], line 1
# ----> 1 df_imputer = IterativeImputer(RandomForestRegressor(), verbose=2).fit_transform(df_imputer)
#
# File ~/miniforge3/envs/NLP_env/lib/python3.8/site-packages/sklearn/utils/_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# File ~/miniforge3/envs/NLP_env/lib/python3.8/site-packages/sklearn/impute/_iterative.py:750, in IterativeImputer.fit_transform(self, X, y)
#     746 for feat_idx in ordered_idx:
#     747     neighbor_feat_idx = self._get_neighbor_feat_idx(
#     748         n_features, feat_idx, abs_corr_mat
#     749     )
# --> 750     Xt, estimator = self._impute_one_feature(
#     751         Xt,
#     752         mask_missing_values,
#     753         feat_idx,
#     754         neighbor_feat_idx,
#     755         estimator=None,
#     756         fit_mode=True,
#     757     )
#     758     estimator_triplet = _ImputerTriplet(
#     759         feat_idx, neighbor_feat_idx, estimator
#     760     )
#     761     self.imputation_sequence_.append(estimator_triplet)
#
# File ~/miniforge3/envs/NLP_env/lib/python3.8/site-packages/sklearn/impute/_iterative.py:401, in IterativeImputer._impute_one_feature(self, X_filled, mask_missing_values, feat_idx, neighbor_feat_idx, estimator, fit_mode)
#     391     X_train = _safe_indexing(
#     392         _safe_indexing(X_filled, neighbor_feat_idx, axis=1),
#     393         ~missing_row_mask,
#     394         axis=0,
#     395     )
#     396     y_train = _safe_indexing(
#     397         _safe_indexing(X_filled, feat_idx, axis=1),
#     398         ~missing_row_mask,
#     399         axis=0,
#     400     )
# --> 401     estimator.fit(X_train, y_train)
#     403 # if no missing values, don't predict
#     404 if np.sum(missing_row_mask) == 0:
#
# File ~/miniforge3/envs/NLP_env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:473, in BaseForest.fit(self, X, y, sample_weight)
#     462 trees = [
#     463     self._make_estimator(append=False, random_state=random_state)
#     464     for i in range(n_more_estimators)
#     465 ]
#     467 # Parallel loop: we prefer the threading backend as the Cython code
#     468 # for fitting the trees is internally releasing the Python GIL
#     469 # making threading more efficient than multiprocessing in
#     470 # that case. However, for joblib 0.12+ we respect any
#     471 # parallel_backend contexts set at a higher level,
#     472 # since correctness does not rely on using threads.
# --> 473 trees = Parallel(
#     474     n_jobs=self.n_jobs,
#     475     verbose=self.verbose,
#     476     prefer="threads",
#     477 )(
#     478     delayed(_parallel_build_trees)(
#     479         t,
#     480         self.bootstrap,
#     481         X,
#     482         y,
#     483         sample_weight,
#     484         i,
#     485         len(trees),
#     486         verbose=self.verbose,
#     487         class_weight=self.class_weight,
#     488         n_samples_bootstrap=n_samples_bootstrap,
#     489     )
#     490     for i, t in enumerate(trees)
#     491 )
#     493 # Collect newly grown trees
#     494 self.estimators_.extend(trees)
#
# File ~/miniforge3/envs/NLP_env/lib/python3.8/site-packages/sklearn/utils/parallel.py:63, in Parallel.__call__(self, iterable)
#      58 config = get_config()
#      59 iterable_with_config = (
#      60     (_with_config(delayed_func, config), args, kwargs)
#      61     for delayed_func, args, kwargs in iterable
#      62 )
# ---> 63 return super().__call__(iterable_with_config)
#
# File ~/miniforge3/envs/NLP_env/lib/python3.8/site-packages/joblib/parallel.py:1088, in Parallel.__call__(self, iterable)
#    1085 if self.dispatch_one_batch(iterator):
#    1086     self._iterating = self._original_iterator is not None
# -> 1088 while self.dispatch_one_batch(iterator):
#    1089     pass
#    1091 if pre_dispatch == "all" or n_jobs == 1:
#    1092     # The iterable was consumed all at once by the above for loop.
#    1093     # No need to wait for async callbacks to trigger to
#    1094     # consumption.
#
# File ~/miniforge3/envs/NLP_env/lib/python3.8/site-packages/joblib/parallel.py:901, in Parallel.dispatch_one_batch(self, iterator)
#     899     return False
#     900 else:
# --> 901     self._dispatch(tasks)
#     902     return True
#
# File ~/miniforge3/envs/NLP_env/lib/python3.8/site-packages/joblib/parallel.py:819, in Parallel._dispatch(self, batch)
#     817 with self._lock:
#     818     job_idx = len(self._jobs)
# --> 819     job = self._backend.apply_async(batch, callback=cb)
#     820     # A job can complete so quickly than its callback is
#     821     # called before we get here, causing self._jobs to
#     822     # grow. To ensure correct results ordering, .insert is
#     823     # used (rather than .append) in the following line
#     824     self._jobs.insert(job_idx, job)
#
# File ~/miniforge3/envs/NLP_env/lib/python3.8/site-packages/joblib/_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~/miniforge3/envs/NLP_env/lib/python3.8/site-packages/joblib/_parallel_backends.py:597, in ImmediateResult.__init__(self, batch)
#     594 def __init__(self, batch):
#     595     # Don't delay the application, to avoid keeping the input
#     596     # arguments in memory
# --> 597     self.results = batch()
#
# File ~/miniforge3/envs/NLP_env/lib/python3.8/site-packages/joblib/parallel.py:288, in BatchedCalls.__call__(self)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File ~/miniforge3/envs/NLP_env/lib/python3.8/site-packages/joblib/parallel.py:288, in <listcomp>(.0)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File ~/miniforge3/envs/NLP_env/lib/python3.8/site-packages/sklearn/utils/parallel.py:123, in _FuncWrapper.__call__(self, *args, **kwargs)
#     121     config = {}
#     122 with config_context(**config):
# --> 123     return self.function(*args, **kwargs)
#
# File ~/miniforge3/envs/NLP_env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:184, in _parallel_build_trees(tree, bootstrap, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     181     elif class_weight == "balanced_subsample":
#     182         curr_sample_weight *= compute_sample_weight("balanced", y, indices=indices)
# --> 184     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     185 else:
#     186     tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# File ~/miniforge3/envs/NLP_env/lib/python3.8/site-packages/sklearn/tree/_classes.py:1247, in DecisionTreeRegressor.fit(self, X, y, sample_weight, check_input)
#    1218 def fit(self, X, y, sample_weight=None, check_input=True):
#    1219     """Build a decision tree regressor from the training set (X, y).
#    1220
#    1221     Parameters
#    (...)
#    1244         Fitted estimator.
#    1245     """
# -> 1247     super().fit(
#    1248         X,
#    1249         y,
#    1250         sample_weight=sample_weight,
#    1251         check_input=check_input,
#    1252     )
#    1253     return self
#
# File ~/miniforge3/envs/NLP_env/lib/python3.8/site-packages/sklearn/tree/_classes.py:379, in BaseDecisionTree.fit(self, X, y, sample_weight, check_input)
#     368 else:
#     369     builder = BestFirstTreeBuilder(
#     370         splitter,
#     371         min_samples_split,
#    (...)
#     376         self.min_impurity_decrease,
#     377     )
# --> 379 builder.build(self.tree_, X, y, sample_weight)
#     381 if self.n_outputs_ == 1 and is_classifier(self):
#     382     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:

# %%
df_clean['SPEC_wheelrim_width_inch'] = df_clean.groupby(['Segment_Name'])['SPEC_wheelrim_width_inch'].transform(lambda x: x.fillna(x.mean()))
df_clean['SPEC_rpm for maximum torque (low)'] = df_clean.groupby(['Segment_Name'])['SPEC_rpm for maximum torque (low)'].transform(lambda x: x.fillna(x.mean()))
df_clean['SPEC_rpm for maximum power (low)'] = df_clean.groupby(['Segment_Name'])['SPEC_rpm for maximum power (low)'].transform(lambda x: x.fillna(x.mean()))
df_clean['OAO_Score'] = df_clean.groupby(['Segment_Name'])['OAO_Score'].transform(lambda x: x.fillna(x.mean()))
df_clean['SPEC_Warranty_wholevehicle_duration(Months)'] = df_clean.groupby(['Segment_Name'])['SPEC_duration (months)1007'].transform(lambda x: x.fillna(x.mean()))
df_clean['SPEC_Warranty_wholevehicle_distance(km)'] = df_clean.groupby(['Segment_Name'])['SPEC_distance (km)1008'].transform(lambda x: x.fillna(x.mean()))
df_clean['SPEC_Warranty_powertrain_duration(Months)'] = df_clean.groupby(['Segment_Name'])['SPEC_duration (months)1010'].transform(lambda x: x.fillna(x.mean()))
df_clean['SPEC_Warranty_powertrain_distance(km)'] = df_clean.groupby(['Segment_Name'])['SPEC_distance (km)1011'].transform(lambda x: x.fillna(x.mean()))
df_clean['SPEC_Warranty_paint_duration(Months)'] = df_clean.groupby(['Segment_Name'])['SPEC_duration (months)1016'].transform(lambda x: x.fillna(x.mean()))
df_clean['SPEC_Warranty_paint_distance(km)'] = df_clean.groupby(['Segment_Name'])['SPEC_distance (km)1017'].transform(lambda x: x.fillna(x.mean()))
df_clean['SPEC_Warranty_anticorrosion_duration(Months)'] = df_clean.groupby(['Segment_Name'])['SPEC_duration (months)1013'].transform(lambda x: x.fillna(x.mean()))
df_clean['SPEC_Warranty_anticorrosion_distance(km)'] = df_clean.groupby(['Segment_Name'])['SPEC_distance (km)1014'].transform(lambda x: x.fillna(x.mean()))
df_clean['SPEC_stroke'] = df_clean.groupby(['Segment_Name'])['SPEC_stroke'].transform(lambda x: x.fillna(x.mean()))
df_clean['SPEC_bore'] = df_clean.groupby(['Segment_Name'])['SPEC_bore'].transform(lambda x: x.fillna(x.mean()))
df_clean['Inventory'] = df_clean.groupby(['Segment_Name'])['Inventory'].transform(lambda x: x.fillna(x.mean()))
df_clean['SPEC_compression ratio'] = df_clean.groupby(['Segment_Name'])['SPEC_compression ratio'].transform(lambda x: x.fillna(x.mean()))
df_clean['SPEC_headroom front (mm)'] = df_clean.groupby(['Segment_Name'])['SPEC_headroom front (mm)'].transform(lambda x: x.fillna(x.mean()))
df_clean['SPEC_axle ratio'] = df_clean.groupby(['Segment_Name'])['SPEC_axle ratio'].transform(lambda x: x.fillna(x.mean()))
df_clean['SPEC_leg room front (mm)'] = df_clean.groupby(['Segment_Name'])['SPEC_leg room front (mm)'].transform(lambda x: x.fillna(x.mean()))
df_clean['SPEC_shoulder room front (mm)'] = df_clean.groupby(['Segment_Name'])['SPEC_shoulder room front (mm)'].transform(lambda x: x.fillna(x.mean()))
df_clean['SPEC_maximum torque lb ft'] = df_clean.groupby(['Segment_Name'])['SPEC_maximum torque lb ft'].transform(lambda x: x.fillna(x.mean()))
df_clean['SPEC_maximum torque Nm'] = df_clean.groupby(['Segment_Name'])['SPEC_maximum torque Nm'].transform(lambda x: x.fillna(x.mean()))
df_clean['SPEC_published kerb weight (kg)'] = df_clean.groupby(['Segment_Name'])['SPEC_published kerb weight (kg)'].transform(lambda x: x.fillna(x.mean()))
df_clean['SPEC_overall width (mm)'] = df_clean.groupby(['Segment_Name'])['SPEC_overall width (mm)'].transform(lambda x: x.fillna(x.mean()))
df_clean['SPEC_cc'] = df_clean.groupby(['Segment_Name'])['SPEC_cc'].transform(lambda x: x.fillna(x.mean()))
df_clean['SPEC_capacity (l)289'] = df_clean.groupby(['Segment_Name'])['SPEC_capacity (l)289'].transform(lambda x: x.fillna(x.mean()))
df_clean['SPEC_number of valves per cylinder'] = df_clean.groupby(['Segment_Name'])['SPEC_number of valves per cylinder'].transform(lambda x: x.fillna(x.mean()))
df_clean['SPEC_number of cylinders'] = df_clean.groupby(['Segment_Name'])['SPEC_number of cylinders'].transform(lambda x: x.fillna(x.mean()))
df_clean['SPEC_overall height (mm)'] = df_clean.groupby(['Segment_Name'])['SPEC_overall height (mm)'].transform(lambda x: x.fillna(x.mean()))
df_clean['SPEC_overall length (mm)'] = df_clean.groupby(['Segment_Name'])['SPEC_overall length (mm)'].transform(lambda x: x.fillna(x.mean()))

edmunds_lst = list(df_clean.filter(like='Edmunds').columns)
for item in edmunds_lst:
    df_clean[item] = df_clean.groupby(['Segment_Name'])[item].transform(lambda x: x.fillna(x.mean()))

rv_lst = list(df_clean.filter(like='RV_').columns)
for item in rv_lst:
    df_clean[item] = df_clean.groupby(['Segment_Name'])[item].transform(lambda x: x.fillna(x.mean()))

ncbs_lst = list(df_clean.filter(like='NCBS').columns)
for item in ncbs_lst:
    df_clean[item] = df_clean.groupby(['Segment_Name'])[item].transform(lambda x: x.fillna(x.mean()))

# %%
pd.DataFrame(df_clean.isna().sum(), columns=['null_number']).sort_values(by='null_number', ascending=False)
# Out:
#                                           null_number
# SPEC_Special edition                                0
# SPEC_roof_standard                                  0
# SPEC_wheelbase_medium                               0
# SPEC_wheelbase_long                                 0
# SPEC_wheelbase_short                                0
# ...                                               ...
# SPEC_includes display777                            0
# SPEC_steering vibration                             0
# SPEC_active without turn signal                     0
# SPEC_includes collision avoidance                   0
# SPEC_Warranty_anticorrosion_distance(km)            0
#
# [1105 rows x 1 columns]

# %%
drop_list = ['SPEC_duration (months)1007', 'SPEC_distance (km)1008', 
'SPEC_distance (km)1017', 'SPEC_duration (months)1016','SPEC_duration (months)1013', 
'SPEC_distance (km)1014','SPEC_duration (months)1010', 'SPEC_distance (km)1011', 'Segment_Name']

# %%
df_clean = df_clean.drop(drop_list, axis=1)

# %%
df_clean.to_csv('df_clean.csv', index=False)
